# %% [markdown]
# # Assignment 4 – Robot in a maze

# %% [markdown]
# In the  fourth assignment, you will delve into the application of RL algorithms to address the real-world challenge of navigating a robot through a maze dubbed 'robot in a maze'. The primary objectives of this assignment include:
#
#  -   Formalizing a practical problem into a Markov Decision Process (MDP).
#  -   Gaining familiarity with the OpenAI Gym framework (recently renamed as Gymnasium) and utilizing it to implement RL agents.
#  -   Applying SARSA and Q-learning algorithms to solve the 'robot in a maze' MDP problem.
#  -   Evaluating the outcomes of the reinforcement learning process and interpreting your findings.
#  -   Reflecting on the distinctions between the two types of RL algorithms employed.
#
# By accomplishing these objectives, you will not only enhance your understanding of RL algorithms but also develop practical skills in formulating and solving complex problems in the context of autonomous navigation within a maze.
#
# In this assignment, you will be developing a robot to navigate its way through a maze. The project is divided into three parts (5 subtasks).
#
#   1. In the first part, you will familiarize yourself with the OpenAI Gym/Gymnasium framework.
#   2. In the second part, we have implemented the environment for you based on the Gym/Gymnasium framework. Your tasks include:
#      2.1. formalizing the problem as an MDP model,
#      2.2. implementing your own RL agents, and
#      2.3. training them to find the shortest route out of a maze.
#   3. Finally, in the third part, you will evaluate and interpret the results obtained from the implemented RL agents

# %% [markdown]
# ## 1. OpenAI gym
#
# Gym/Gymnasium (https://gymnasium.farama.org/) is a widely used standard toolkit for developing and comparing reinforcement learning algorithms. Gymnasium is the maintained fork of OpenAI’s Gym library (more on this recent change is available if you're interested: https://farama.org/Announcing-The-Farama-Foundation).
#
# Gym/Gymnasium makes no assumptions about the structure of your agent and is compatible with any machine learning library, such as TensorFlow or Theano.
#
# The library is a collection of test problems — environments — that you can use to develop your reinforcement learning algorithms. These environments have a shared interface, allowing you to write general algorithms.
#
# First, we download and install the Gym/Gymnasium library. Then, import the Gymnasium class.

# %%
# !pip install gymnasium
# Out:
# Requirement already satisfied: gymnasium in c:\users\rwjhe\appdata\local\programs\python\python311\lib\site-packages (0.29.1)
# Requirement already satisfied: numpy>=1.21.0 in c:\users\rwjhe\appdata\local\programs\python\python311\lib\site-packages (from gymnasium) (1.25.2)
# Requirement already satisfied: cloudpickle>=1.2.0 in c:\users\rwjhe\appdata\local\programs\python\python311\lib\site-packages (from gymnasium) (3.0.0)
# Requirement already satisfied: typing-extensions>=4.3.0 in c:\users\rwjhe\appdata\local\programs\python\python311\lib\site-packages (from gymnasium) (4.7.1)
# Requirement already satisfied: farama-notifications>=0.0.1 in c:\users\rwjhe\appdata\local\programs\python\python311\lib\site-packages (from gymnasium) (0.0.4)
# [notice] A new release of pip is available: 23.3.1 -> 23.3.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# We are now going to explain how the RL framework of gym works.
# - An **ENVIRONMENT**,
# - You also have an **AGENT**,
# - In MDP problems, such as ours, the **ENVIRONMENT** provides an **OBSERVATION**, which represents the state of the **ENVIRONMENT** at the current moment.
# - The agent takes an **ACTION** based on its **OBSERVATION**,
# <!-- When a single **ACTION** is chosen and fed to our **ENVIRONMENT**, the **ENVIRONMENT** measures how good the action was taken and produces a **REWARD**, which is usually a numeric value. -->
# - When the agent takes an ACTION, the ENVIRONMENT assesses the effectiveness of the action and generates a REWARD, which is usually a numeric value.
#
# Please read the 'Basic usage' https://gymnasium.farama.org/content/basic_usage/ for better understanding the framework.  And do not forget import gymnasium before running other codes.

# %% [markdown]
#  ## 2. Tasks
#
# Next, you will tackle a practical Markov Decision Process (MDP) problem, the 'robot in a maze,' based on the gym framework. Your task involves implementing an RL agent and training it to discover the shortest route to achieve the maze goal. In this MDP, the environment is represented as a grid world (a maze), with the agent being a robot. At each time step, the robot begins at a random location and can move within the grid world. The overarching objective is to find the way out, reaching the final location. Consequently, you will need to identify a fixed goal position within the maze.

# %% [markdown]
# ### 2.1 Model the practical task into a MDP
#
# To solve a RL problem, we start with formalizing the problem into a MDP model. Please describe this MDP model in your report.
#
# Notice: No empricial data provided in this assignment, so the point of 'data description and exploration' will be given to this step.
#
# While exploring your MDP model, you shall think about questions such as:
# - What is the environment? How does it look like?
# - What simulated data can your RL agent observe from the environment? How does it look like?
# - Which data is considered as the state? Which data is considered as the reward?

# %% [markdown]
# #### Set up the environment
#
# There is no need to implement your own environment; you should use the environment provided in the file **environment.py**. However, please ensure to take a look at it so that you understand the inner workings of this environment.
#
# The core gym interface is **Env**, which serves as the unified environment interface. The following are the Env methods you should be familiar with:
#
# - reset(self): Reset the environment's state and return the observation.
# - step(self, action): Advance the environment by one timestep and return the observation, reward, done, and info.
# - render(self, mode='rgb_array'): Render one frame of the environment. The default mode will produce something human-friendly, such as pop up a window. However, in this assignment, there is no need to create a pop-up window.
#
# Please note that you need to install the [mazelab](https://github.com/yupei-du/mazelab.git) package, from **Yupei Du's** repository, to run the environment (a file with required packages is also provided). If you run the cell below for the first time, make sure to restart the IPython notebook at least once.

# %%
# !git clone https://github.com/yupei-du/mazelab.git
# !pip install mazelab
# !pip install pandas
# !pip install seaborn

# %% [markdown]
# You can now check whether the required packages (e.g. mazela, pandas, tqdm, seaborn) are installed. Please install the ones are missing.
#
# ATTENTION: To run the given code, please use the python version 3.7-3.9, and the numpy version < 1.23

# %%
# !pip list
# Out:
# Package                   Version
# ------------------------- ------------
# annotated-types           0.5.0
# ansi2html                 1.8.0
# anyio                     4.0.0
# argon2-cffi               23.1.0
# argon2-cffi-bindings      21.2.0
# arrow                     1.2.3
# asttokens                 2.4.0
# async-lru                 2.0.4
# attrs                     23.1.0
# Babel                     2.12.1
# backcall                  0.2.0
# beautifulsoup4            4.12.2
# bleach                    6.0.0
# blinker                   1.6.2
# blis                      0.7.10
# branca                    0.6.0
# catalogue                 2.0.9
# certifi                   2023.7.22
# cffi                      1.15.1
# charset-normalizer        3.2.0
# click                     8.1.7
# cloudpickle               3.0.0
# colorama                  0.4.6
# comm                      0.1.4
# confection                0.1.3
# contourpy                 1.2.0
# cycler                    0.12.1
# cymem                     2.0.7
# dash                      2.13.0
# dash-bootstrap-components 1.5.0
# dash-core-components      2.0.0
# dash-html-components      2.0.0
# dash-table                5.0.0
# debugpy                   1.6.7.post1
# decorator                 5.1.1
# defusedxml                0.7.1
# dill                      0.3.7
# emoji                     2.9.0
# en-core-web-sm            3.6.0
# executing                 1.2.0
# Farama-Notifications      0.0.4
# fastjsonschema            2.18.0
# Flask                     2.2.5
# folium                    0.14.0
# fonttools                 4.44.3
# fqdn                      1.5.1
# funcy                     2.0
# gensim                    4.3.2
# graphviz                  0.20.1
# gym                       0.26.2
# gym-notices               0.0.8
# gymnasium                 0.29.1
# idna                      3.4
# imageio                   2.33.1
# ipykernel                 6.25.2
# ipython                   8.15.0
# isoduration               20.11.0
# itsdangerous              2.1.2
# jedi                      0.19.0
# Jinja2                    3.1.2
# joblib                    1.3.2
# json5                     0.9.14
# jsonpointer               2.4
# jsonschema                4.19.0
# jsonschema-specifications 2023.7.1
# jupyter_client            8.3.1
# jupyter_core              5.3.1
# jupyter-events            0.7.0
# jupyter-lsp               2.2.0
# jupyter_server            2.7.3
# jupyter_server_terminals  0.4.4
# jupyterlab                4.0.5
# jupyterlab-pygments       0.2.2
# jupyterlab_server         2.24.0
# kiwisolver                1.4.5
# langcodes                 3.3.0
# lazy_loader               0.3
# lxml                      4.9.3
# MarkupSafe                2.1.3
# matplotlib                3.8.1
# matplotlib-inline         0.1.6
# mazelab                   0.2.0
# mistune                   3.0.1
# murmurhash                1.0.9
# nbclient                  0.8.0
# nbconvert                 7.8.0
# nbformat                  5.9.2
# nest-asyncio              1.5.7
# networkx                  3.2.1
# nl-core-news-sm           3.6.0
# notebook_shim             0.2.3
# numexpr                   2.8.8
# numpy                     1.25.2
# overrides                 7.4.0
# packaging                 23.1
# pandas                    2.1.0
# pandocfilters             1.5.0
# parso                     0.8.3
# pathy                     0.10.2
# patsy                     0.5.3
# pickleshare               0.7.5
# Pillow                    10.1.0
# pip                       23.3.1
# platformdirs              3.10.0
# plotly                    5.16.1
# preshed                   3.0.8
# prometheus-client         0.17.1
# prompt-toolkit            3.0.39
# psutil                    5.9.5
# pure-eval                 0.2.2
# pycparser                 2.21
# pydantic                  2.3.0
# pydantic_core             2.6.3
# pyfunctional              1.4.3
# Pygments                  2.16.1
# pyLDAvis                  3.4.1
# PyOpenGL                  3.1.7
# pyparsing                 3.1.1
# python-dateutil           2.8.2
# python-json-logger        2.0.7
# pytz                      2023.3.post1
# pywin32                   306
# pywinpty                  2.0.11
# PyYAML                    6.0.1
# pyzmq                     25.1.1
# referencing               0.30.2
# requests                  2.31.0
# retrying                  1.3.4
# rfc3339-validator         0.1.4
# rfc3986-validator         0.1.1
# rpds-py                   0.10.2
# scikit-image              0.22.0
# scikit-learn              1.3.2
# scipy                     1.11.2
# seaborn                   0.13.0
# Send2Trash                1.8.2
# setuptools                65.5.0
# six                       1.16.0
# sklearn                   0.0.post11
# sklearn-utils             0.0.15
# smart-open                6.4.0
# sniffio                   1.3.0
# soupsieve                 2.5
# spacy                     3.6.1
# spacy-legacy              3.0.12
# spacy-loggers             1.0.5
# srsly                     2.4.7
# stack-data                0.6.2
# statsmodels               0.14.0
# tabulate                  0.9.0
# tenacity                  8.2.3
# terminado                 0.17.1
# thinc                     8.1.12
# threadpoolctl             3.2.0
# tifffile                  2023.12.9
# tinycss2                  1.2.1
# tornado                   6.3.3
# tqdm                      4.66.1
# traitlets                 5.9.0
# typer                     0.9.0
# typing_extensions         4.7.1
# tzdata                    2023.3
# uri-template              1.3.0
# urllib3                   2.0.4
# wasabi                    1.1.2
# wcwidth                   0.2.6
# webcolors                 1.13
# webencodings              0.5.1
# websocket-client          1.6.2
# Werkzeug                  2.2.3
# wordcloud                 1.9.3
# [notice] A new release of pip is available: 23.3.1 -> 23.3.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# We also provide a few helper functions to make it easier to debug your agents.
#  - `animate_run` will enable you to see the agent's behavior. It takes a list of images which can be produced by the `env.render` function of the environment
#  - `visualize_agent_brain` will provide you with a way to visualize the agents learned q_table. Use it after you have implemented and trained your agents. The first plot will show the highest q-value per state (position on the map) and the second will tell you which action the agent would choose at that state/position. It takes the environment and the agent as input.
#
# Below you will find a basic example of how the animation function works. Please notice that: whenever you **reset()** the environment, the agent will start at a random position (a different state).

# %%
# libraries
from IPython import get_ipython
import random
from mazelab.generators import random_maze, morris_water_maze
import matplotlib.pyplot as plt
from IPython import display
from mazelab.solvers import dijkstra_solver
import seaborn as sns
from tqdm.notebook import tqdm
from others.others.environment import TaskEnv
from typing import Tuple, List
import itertools as it
import numpy as np
import pandas as pd
import time

# %%
# The helper functions

def animate_run(data:List[np.ndarray]):
    init_img = data[0]
    remaining_img = data[1:]
    img_container = plt.imshow(init_img)  # only call this once
    for img in remaining_img:
        img_container.set_data(img)  # just update the data
        display.display(plt.gcf())
        display.clear_output(wait=True)
        time.sleep(0.2)


def visualize_agent_brain(agent, env: TaskEnv):
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10, 4))
    ax1.set_title("Highest state value at position (x,y)")
    state_value_map = agent.q_table.max(axis=2)
    sns.heatmap(state_value_map, ax=ax1)

    ax2.set_title("Chosen action at position (x,y)")
    n = env.action_space.n + 1
    path = env.maze.objects.free.positions
    decisions_map = np.array([[x_, y_, agent.select_action([x_, y_]) + 1] for x_, y_ in path])
    state_action_map = np.zeros_like(agent.q_table.max(axis=2))
    state_action_map[decisions_map[:, 0], decisions_map[:, 1]] = decisions_map[:, 2]
    cmap = sns.color_palette("viridis", n)
    sns.heatmap(state_action_map, cmap=cmap, ax=ax2)
    colorbar = ax2.collections[0].colorbar
    r = (colorbar.vmax) - colorbar.vmin
    colorbar.set_ticks([colorbar.vmin + r / n * (0.5 + i) for i in range(n)])
    colorbar.set_ticklabels(['N/A', 'north', 'south', 'west', 'east'])
    fig.tight_layout()
    return plt.show()


env = TaskEnv()
env.reset()
impassable_array = env.unwrapped.maze.to_impassable()
motions = env.unwrapped.motions
start = env.unwrapped.maze.objects.agent.positions[0]
goal = env.unwrapped.maze.objects.goal.positions[0]
actions = dijkstra_solver(impassable_array, motions, start, goal)
print(actions)

imgs = []
rewards = 0.0
for action in actions:
    _, reward, _, _ = env.step(action)
    rewards += reward
    imgs.append(env.render("rgb_array"))
print(rewards)

animate_run(imgs)
plt.show()

# %% [markdown]
# ### 2.2  Implement the agents
#
# In this part, you are expected to implement two RL agents.
#
# - Agent 1 uses the Q-learning algorithm to learn the optimal solution
# - Agent 2 uses the SARSA algorithm to learn the optimal solution. To decide the action to take at each time step,  this agent uses the epsilon greedy action selection.
#
# Here, we have also provided an example agent: the Random Agent.  It follows a random policy to move at each step (randomly selecting an action). You can use this example agent as a baseline to evaluate your agents.

# %%
# Random agent
class RandomAgent():
    def __init__(self, env: TaskEnv):
        self.epsilon = 1  # A random agent "explores" always, so epsilon will be 1
        self.alpha = 0  # A random agent never learns, so there's no need for a learning rate
        self.gamma = 0  # A random agent does not update it's q-table. Hence, it's zero.
        self.q_table = np.zeros(env.observation_space.shape + (env.action_space.n, ), dtype=float)
        self.actions = env.action_space

    def select_action(self, state: Tuple[int, int], use_greedy_strategy: bool = False):
        if not use_greedy_strategy:
            if random.random() < self.epsilon:
                next_action = self.actions.sample()
                return next_action

        x, y = state
        max_val = np.max(self.q_table[x, y, :])
        find_max_val = np.where(self.q_table[x, y, :] == max_val)
        next_action = np.random.choice(find_max_val[0])
        return next_action

# %%
# Q-Learning agent
class QL_Agent():
    def __init__(self, 
                 env: TaskEnv,
                 epsilon: float = 0.1,
                 alpha: float = 0.5,
                 gamma: float = 0.9):
        self.epsilon = epsilon
        self.alpha = alpha
        self.gamma = gamma
        self.q_table = np.zeros(env.observation_space.shape + (env.action_space.n, ), dtype=float)
        self.actions = env.action_space

    def select_action(self, state: Tuple[int, int], use_greedy_strategy: bool = False):
        if not use_greedy_strategy:
            if random.random() < self.epsilon:
                next_action = self.actions.sample()
                return next_action

        x, y = state
        max_val = np.max(self.q_table[x, y, :])
        find_max_val = np.where(self.q_table[x, y, :] == max_val)
        next_action = np.random.choice(find_max_val[0]) # Epsilon-greedy policy
        return next_action

    def learn(self, state, action, next_state, reward, done):
        x, y = state
        next_x, next_y = next_state
        max_val = (not done) * np.max(self.q_table[next_x, next_y, :])
        self.q_table[x, y, action] += self.alpha * (reward + self.gamma * max_val - self.q_table[x, y, action])

# %%
# TODO: SARSA agent
class SARSA_Agent():
    def __init__(self, 
                 env: TaskEnv,
                 epsilon: float = 0.1,
                 alpha: float = 0.5,
                 gamma: float = 0.9):
        self.epsilon = epsilon
        self.alpha = alpha
        self.gamma = gamma
        self.q_table = np.zeros(env.observation_space.shape + (env.action_space.n, ), dtype=float)
        self.actions = env.action_space

    def select_action(self, state: Tuple[int, int], use_greedy_strategy: bool = False):
        if not use_greedy_strategy:
            if random.random() < self.epsilon:
                next_action = self.actions.sample()
                return next_action

        max_val = np.max(self.q_table[state, :])
        find_max_val = np.where(self.q_table[state, :] == max_val)
        next_action = np.random.choice(find_max_val[0]) # Epsilon-greedy policy
        return next_action

    def learn(self, state, action, next_state, next_action, reward, done):
        next_x, next_y = next_state
        next_val = (not done) * self.q_table[next_x, next_y, next_action]
        self.q_table[state, action] += self.alpha * (reward + self.gamma * next_val - self.q_table[state, action])

# %% [markdown]
# ### 2.3 Run the simulation
#
# Now, you write code for running a simulation. In each run, you shall setup the epsilon parameter.

# %%
# TODO: run the simulation

env = TaskEnv()

# Set up hyperparameters
epsilon = 0.1
alpha = 0.5
gamma = 0.9
agent = QL_Agent(env, epsilon, alpha, gamma)

for episode in tqdm(range(1000)):
    state = env.reset()
    done = False

    while not done:
        action = agent.select_action(state)
        next_state, reward, terminated, truncated = env.step(action)
        done = terminated or truncated

        agent.learn(state, action, next_state, reward, done)
        state = next_state
        env.render()
    
    print(f"Episode: {episode}, Action: {action}, Reward: {reward}, Done: {done}")
# Out:
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Episode: 0, Action: 3, Reward: -1, Done: True
# Episode: 1, Action: 0, Reward: -1, Done: True
# Episode: 2, Action: 2, Reward: -1, Done: True
# Episode: 3, Action: 3, Reward: -1, Done: True
# Episode: 4, Action: 2, Reward: -1, Done: True
# Episode: 5, Action: 3, Reward: -1, Done: True
# Episode: 6, Action: 2, Reward: 1, Done: True
# Episode: 7, Action: 1, Reward: -1, Done: True
# Episode: 8, Action: 2, Reward: -1, Done: True
# Episode: 9, Action: 2, Reward: 1, Done: True
# Episode: 10, Action: 2, Reward: 1, Done: True
# Episode: 11, Action: 3, Reward: -1, Done: True
# Episode: 12, Action: 1, Reward: -1, Done: True
# Episode: 13, Action: 3, Reward: 1, Done: True
# Episode: 14, Action: 2, Reward: -1, Done: True
# Episode: 15, Action: 1, Reward: -1, Done: True
# Episode: 16, Action: 2, Reward: 1, Done: True
# Episode: 17, Action: 1, Reward: -1, Done: True
# Episode: 18, Action: 2, Reward: 1, Done: True
# Episode: 19, Action: 2, Reward: -1, Done: True
# Episode: 20, Action: 0, Reward: -1, Done: True
# Episode: 21, Action: 3, Reward: 1, Done: True
# Episode: 22, Action: 3, Reward: -1, Done: True
# Episode: 23, Action: 2, Reward: 1, Done: True
# Episode: 24, Action: 3, Reward: 1, Done: True
# Episode: 25, Action: 1, Reward: -1, Done: True
# Episode: 26, Action: 1, Reward: -1, Done: True
# Episode: 27, Action: 0, Reward: -1, Done: True
# Episode: 28, Action: 2, Reward: -1, Done: True
# Episode: 29, Action: 0, Reward: -1, Done: True
# Episode: 30, Action: 3, Reward: -1, Done: True
# Episode: 31, Action: 3, Reward: -1, Done: True
# Episode: 32, Action: 2, Reward: 1, Done: True
# Episode: 33, Action: 2, Reward: -1, Done: True
# Episode: 34, Action: 2, Reward: -1, Done: True
# Episode: 35, Action: 2, Reward: -1, Done: True
# Episode: 36, Action: 2, Reward: 1, Done: True
# Episode: 37, Action: 0, Reward: -1, Done: True
# Episode: 38, Action: 3, Reward: 1, Done: True
# Episode: 39, Action: 2, Reward: -1, Done: True
# Episode: 40, Action: 3, Reward: -1, Done: True
# Episode: 41, Action: 3, Reward: -1, Done: True
# Episode: 42, Action: 3, Reward: -1, Done: True
# Episode: 43, Action: 0, Reward: -1, Done: True
# Episode: 44, Action: 1, Reward: -1, Done: True
# Episode: 45, Action: 1, Reward: -1, Done: True
# Episode: 46, Action: 2, Reward: -1, Done: True
# Episode: 47, Action: 3, Reward: -1, Done: True
# Episode: 48, Action: 0, Reward: -1, Done: True
# Episode: 49, Action: 3, Reward: 1, Done: True
# Episode: 50, Action: 1, Reward: -1, Done: True
# Episode: 51, Action: 2, Reward: 1, Done: True
# Episode: 52, Action: 2, Reward: 1, Done: True
# Episode: 53, Action: 1, Reward: -1, Done: True
# Episode: 54, Action: 3, Reward: -1, Done: True
# Episode: 55, Action: 2, Reward: 1, Done: True
# Episode: 56, Action: 2, Reward: -1, Done: True
# Episode: 57, Action: 3, Reward: -1, Done: True
# Episode: 58, Action: 1, Reward: -1, Done: True
# Episode: 59, Action: 3, Reward: 1, Done: True
# Episode: 60, Action: 2, Reward: 1, Done: True
# Episode: 61, Action: 0, Reward: -1, Done: True
# Episode: 62, Action: 1, Reward: -1, Done: True
# Episode: 63, Action: 3, Reward: -1, Done: True
# Episode: 64, Action: 2, Reward: -1, Done: True
# Episode: 65, Action: 3, Reward: -1, Done: True
# Episode: 66, Action: 3, Reward: -1, Done: True
# Episode: 67, Action: 2, Reward: -1, Done: True
# Episode: 68, Action: 3, Reward: -1, Done: True
# Episode: 69, Action: 0, Reward: -1, Done: True
# Episode: 70, Action: 1, Reward: -1, Done: True
# Episode: 71, Action: 3, Reward: 1, Done: True
# Episode: 72, Action: 3, Reward: -1, Done: True
# Episode: 73, Action: 0, Reward: -1, Done: True
# Episode: 74, Action: 2, Reward: 1, Done: True
# Episode: 75, Action: 2, Reward: 1, Done: True
# Episode: 76, Action: 1, Reward: -1, Done: True
# Episode: 77, Action: 2, Reward: -1, Done: True
# Episode: 78, Action: 1, Reward: -1, Done: True
# Episode: 79, Action: 3, Reward: -1, Done: True
# Episode: 80, Action: 2, Reward: 1, Done: True
# Episode: 81, Action: 3, Reward: -1, Done: True
# Episode: 82, Action: 2, Reward: -1, Done: True
# Episode: 83, Action: 2, Reward: 1, Done: True
# Episode: 84, Action: 3, Reward: -1, Done: True
# Episode: 85, Action: 3, Reward: 1, Done: True
# Episode: 86, Action: 2, Reward: 1, Done: True
# Episode: 87, Action: 3, Reward: 1, Done: True
# Episode: 88, Action: 3, Reward: -1, Done: True
# Episode: 89, Action: 2, Reward: -1, Done: True
# Episode: 90, Action: 1, Reward: -1, Done: True
# Episode: 91, Action: 1, Reward: -1, Done: True
# Episode: 92, Action: 2, Reward: 1, Done: True
# Episode: 93, Action: 3, Reward: -1, Done: True
# Episode: 94, Action: 2, Reward: 1, Done: True
# Episode: 95, Action: 2, Reward: 1, Done: True
# Episode: 96, Action: 2, Reward: 1, Done: True
# Episode: 97, Action: 1, Reward: -1, Done: True
# Episode: 98, Action: 2, Reward: -1, Done: True
# Episode: 99, Action: 1, Reward: -1, Done: True
# Episode: 100, Action: 3, Reward: 1, Done: True
# Episode: 101, Action: 2, Reward: 1, Done: True
# Episode: 102, Action: 3, Reward: -1, Done: True
# Episode: 103, Action: 1, Reward: -1, Done: True
# Episode: 104, Action: 1, Reward: -1, Done: True
# Episode: 105, Action: 3, Reward: 1, Done: True
# Episode: 106, Action: 2, Reward: 1, Done: True
# Episode: 107, Action: 2, Reward: 1, Done: True
# Episode: 108, Action: 3, Reward: 1, Done: True
# Episode: 109, Action: 1, Reward: -1, Done: True
# Episode: 110, Action: 1, Reward: -1, Done: True
# Episode: 111, Action: 3, Reward: -1, Done: True
# Episode: 112, Action: 0, Reward: -1, Done: True
# Episode: 113, Action: 2, Reward: -1, Done: True
# Episode: 114, Action: 0, Reward: -1, Done: True
# Episode: 115, Action: 2, Reward: -1, Done: True
# Episode: 116, Action: 2, Reward: 1, Done: True
# Episode: 117, Action: 1, Reward: -1, Done: True
# Episode: 118, Action: 0, Reward: -1, Done: True
# Episode: 119, Action: 3, Reward: 1, Done: True
# Episode: 120, Action: 2, Reward: 1, Done: True
# Episode: 121, Action: 2, Reward: -1, Done: True
# Episode: 122, Action: 3, Reward: -1, Done: True
# Episode: 123, Action: 0, Reward: -1, Done: True
# Episode: 124, Action: 2, Reward: 1, Done: True
# Episode: 125, Action: 1, Reward: -1, Done: True
# Episode: 126, Action: 2, Reward: 1, Done: True
# Episode: 127, Action: 1, Reward: -1, Done: True
# Episode: 128, Action: 2, Reward: 1, Done: True
# Episode: 129, Action: 3, Reward: -1, Done: True
# Episode: 130, Action: 3, Reward: 1, Done: True
# Episode: 131, Action: 2, Reward: 1, Done: True
# Episode: 132, Action: 2, Reward: 1, Done: True
# Episode: 133, Action: 2, Reward: 1, Done: True
# Episode: 134, Action: 3, Reward: -1, Done: True
# Episode: 135, Action: 3, Reward: 1, Done: True
# Episode: 136, Action: 1, Reward: -1, Done: True
# Episode: 137, Action: 2, Reward: 1, Done: True
# Episode: 138, Action: 2, Reward: 1, Done: True
# Episode: 139, Action: 2, Reward: 1, Done: True
# Episode: 140, Action: 0, Reward: -1, Done: True
# Episode: 141, Action: 2, Reward: 1, Done: True
# Episode: 142, Action: 1, Reward: -1, Done: True
# Episode: 143, Action: 3, Reward: -1, Done: True
# Episode: 144, Action: 2, Reward: 1, Done: True
# Episode: 145, Action: 2, Reward: 1, Done: True
# Episode: 146, Action: 3, Reward: -1, Done: True
# Episode: 147, Action: 2, Reward: 1, Done: True
# Episode: 148, Action: 2, Reward: -1, Done: True
# Episode: 149, Action: 1, Reward: -1, Done: True
# Episode: 150, Action: 1, Reward: -1, Done: True
# Episode: 151, Action: 2, Reward: -1, Done: True
# Episode: 152, Action: 3, Reward: 1, Done: True
# Episode: 153, Action: 2, Reward: -1, Done: True
# Episode: 154, Action: 1, Reward: -1, Done: True
# Episode: 155, Action: 1, Reward: -1, Done: True
# Episode: 156, Action: 2, Reward: 1, Done: True
# Episode: 157, Action: 3, Reward: -1, Done: True
# Episode: 158, Action: 2, Reward: 1, Done: True
# Episode: 159, Action: 2, Reward: 1, Done: True
# Episode: 160, Action: 2, Reward: 1, Done: True
# Episode: 161, Action: 1, Reward: -1, Done: True
# Episode: 162, Action: 3, Reward: 1, Done: True
# Episode: 163, Action: 3, Reward: -1, Done: True
# Episode: 164, Action: 3, Reward: -1, Done: True
# Episode: 165, Action: 2, Reward: 1, Done: True
# Episode: 166, Action: 2, Reward: 1, Done: True
# Episode: 167, Action: 3, Reward: -1, Done: True
# Episode: 168, Action: 2, Reward: 1, Done: True
# Episode: 169, Action: 0, Reward: -1, Done: True
# Episode: 170, Action: 2, Reward: 1, Done: True
# Episode: 171, Action: 2, Reward: 1, Done: True
# Episode: 172, Action: 0, Reward: -1, Done: True
# Episode: 173, Action: 2, Reward: -1, Done: True
# Episode: 174, Action: 1, Reward: -1, Done: True
# Episode: 175, Action: 2, Reward: -1, Done: True
# Episode: 176, Action: 2, Reward: 1, Done: True
# Episode: 177, Action: 2, Reward: 1, Done: True
# Episode: 178, Action: 2, Reward: 1, Done: True
# Episode: 179, Action: 2, Reward: 1, Done: True
# Episode: 180, Action: 3, Reward: -1, Done: True
# Episode: 181, Action: 2, Reward: 1, Done: True
# Episode: 182, Action: 2, Reward: 1, Done: True
# Episode: 183, Action: 3, Reward: 1, Done: True
# Episode: 184, Action: 3, Reward: -1, Done: True
# Episode: 185, Action: 2, Reward: 1, Done: True
# Episode: 186, Action: 2, Reward: 1, Done: True
# Episode: 187, Action: 3, Reward: -1, Done: True
# Episode: 188, Action: 1, Reward: -1, Done: True
# Episode: 189, Action: 3, Reward: -1, Done: True
# Episode: 190, Action: 1, Reward: -1, Done: True
# Episode: 191, Action: 3, Reward: -1, Done: True
# Episode: 192, Action: 2, Reward: 1, Done: True
# Episode: 193, Action: 2, Reward: 1, Done: True
# Episode: 194, Action: 2, Reward: 1, Done: True
# Episode: 195, Action: 2, Reward: 1, Done: True
# Episode: 196, Action: 1, Reward: -1, Done: True
# Episode: 197, Action: 2, Reward: 1, Done: True
# Episode: 198, Action: 3, Reward: 1, Done: True
# Episode: 199, Action: 1, Reward: -1, Done: True
# Episode: 200, Action: 2, Reward: 1, Done: True
# Episode: 201, Action: 1, Reward: -1, Done: True
# Episode: 202, Action: 2, Reward: 1, Done: True
# Episode: 203, Action: 3, Reward: 1, Done: True
# Episode: 204, Action: 2, Reward: 1, Done: True
# Episode: 205, Action: 2, Reward: 1, Done: True
# Episode: 206, Action: 2, Reward: 1, Done: True
# Episode: 207, Action: 3, Reward: -1, Done: True
# Episode: 208, Action: 2, Reward: 1, Done: True
# Episode: 209, Action: 2, Reward: 1, Done: True
# Episode: 210, Action: 2, Reward: 1, Done: True
# Episode: 211, Action: 2, Reward: 1, Done: True
# Episode: 212, Action: 2, Reward: 1, Done: True
# Episode: 213, Action: 2, Reward: 1, Done: True
# Episode: 214, Action: 2, Reward: 1, Done: True
# Episode: 215, Action: 2, Reward: 1, Done: True
# Episode: 216, Action: 1, Reward: -1, Done: True
# Episode: 217, Action: 2, Reward: 1, Done: True
# Episode: 218, Action: 2, Reward: 1, Done: True
# Episode: 219, Action: 0, Reward: -1, Done: True
# Episode: 220, Action: 3, Reward: 1, Done: True
# Episode: 221, Action: 2, Reward: 1, Done: True
# Episode: 222, Action: 2, Reward: 1, Done: True
# Episode: 223, Action: 1, Reward: -1, Done: True
# Episode: 224, Action: 2, Reward: 1, Done: True
# Episode: 225, Action: 3, Reward: -1, Done: True
# Episode: 226, Action: 2, Reward: 1, Done: True
# Episode: 227, Action: 2, Reward: 1, Done: True
# Episode: 228, Action: 2, Reward: -1, Done: True
# Episode: 229, Action: 2, Reward: 1, Done: True
# Episode: 230, Action: 0, Reward: -1, Done: True
# Episode: 231, Action: 2, Reward: 1, Done: True
# Episode: 232, Action: 2, Reward: 1, Done: True
# Episode: 233, Action: 3, Reward: -1, Done: True
# Episode: 234, Action: 0, Reward: -1, Done: True
# Episode: 235, Action: 3, Reward: 1, Done: True
# Episode: 236, Action: 2, Reward: 1, Done: True
# Episode: 237, Action: 2, Reward: 1, Done: True
# Episode: 238, Action: 0, Reward: -1, Done: True
# Episode: 239, Action: 2, Reward: 1, Done: True
# Episode: 240, Action: 2, Reward: 1, Done: True
# Episode: 241, Action: 2, Reward: 1, Done: True
# Episode: 242, Action: 2, Reward: 1, Done: True
# Episode: 243, Action: 0, Reward: -1, Done: True
# Episode: 244, Action: 2, Reward: 1, Done: True
# Episode: 245, Action: 2, Reward: 1, Done: True
# Episode: 246, Action: 2, Reward: 1, Done: True
# Episode: 247, Action: 2, Reward: 1, Done: True
# Episode: 248, Action: 2, Reward: 1, Done: True
# Episode: 249, Action: 2, Reward: 1, Done: True
# Episode: 250, Action: 3, Reward: 1, Done: True
# Episode: 251, Action: 2, Reward: 1, Done: True
# Episode: 252, Action: 2, Reward: 1, Done: True
# Episode: 253, Action: 1, Reward: -1, Done: True
# Episode: 254, Action: 3, Reward: 1, Done: True
# Episode: 255, Action: 1, Reward: -1, Done: True
# Episode: 256, Action: 2, Reward: 1, Done: True
# Episode: 257, Action: 2, Reward: 1, Done: True
# Episode: 258, Action: 0, Reward: -1, Done: True
# Episode: 259, Action: 2, Reward: 1, Done: True
# Episode: 260, Action: 2, Reward: 1, Done: True
# Episode: 261, Action: 2, Reward: 1, Done: True
# Episode: 262, Action: 2, Reward: 1, Done: True
# Episode: 263, Action: 3, Reward: 1, Done: True
# Episode: 264, Action: 2, Reward: 1, Done: True
# Episode: 265, Action: 2, Reward: 1, Done: True
# Episode: 266, Action: 3, Reward: -1, Done: True
# Episode: 267, Action: 2, Reward: 1, Done: True
# Episode: 268, Action: 2, Reward: 1, Done: True
# Episode: 269, Action: 2, Reward: 1, Done: True
# Episode: 270, Action: 2, Reward: 1, Done: True
# Episode: 271, Action: 2, Reward: 1, Done: True
# Episode: 272, Action: 2, Reward: 1, Done: True
# Episode: 273, Action: 3, Reward: 1, Done: True
# Episode: 274, Action: 2, Reward: 1, Done: True
# Episode: 275, Action: 2, Reward: 1, Done: True
# Episode: 276, Action: 2, Reward: 1, Done: True
# Episode: 277, Action: 2, Reward: 1, Done: True
# Episode: 278, Action: 2, Reward: 1, Done: True
# Episode: 279, Action: 3, Reward: 1, Done: True
# Episode: 280, Action: 2, Reward: 1, Done: True
# Episode: 281, Action: 2, Reward: 1, Done: True
# Episode: 282, Action: 2, Reward: 1, Done: True
# Episode: 283, Action: 3, Reward: -1, Done: True
# Episode: 284, Action: 3, Reward: -1, Done: True
# Episode: 285, Action: 2, Reward: -1, Done: True
# Episode: 286, Action: 2, Reward: 1, Done: True
# Episode: 287, Action: 2, Reward: 1, Done: True
# Episode: 288, Action: 2, Reward: 1, Done: True
# Episode: 289, Action: 2, Reward: 1, Done: True
# Episode: 290, Action: 2, Reward: 1, Done: True
# Episode: 291, Action: 2, Reward: 1, Done: True
# Episode: 292, Action: 2, Reward: 1, Done: True
# Episode: 293, Action: 1, Reward: -1, Done: True
# Episode: 294, Action: 2, Reward: 1, Done: True
# Episode: 295, Action: 3, Reward: 1, Done: True
# Episode: 296, Action: 3, Reward: -1, Done: True
# Episode: 297, Action: 3, Reward: -1, Done: True
# Episode: 298, Action: 2, Reward: 1, Done: True
# Episode: 299, Action: 1, Reward: -1, Done: True
# Episode: 300, Action: 2, Reward: 1, Done: True
# Episode: 301, Action: 2, Reward: 1, Done: True
# Episode: 302, Action: 2, Reward: 1, Done: True
# Episode: 303, Action: 0, Reward: -1, Done: True
# Episode: 304, Action: 3, Reward: 1, Done: True
# Episode: 305, Action: 2, Reward: 1, Done: True
# Episode: 306, Action: 2, Reward: 1, Done: True
# Episode: 307, Action: 2, Reward: 1, Done: True
# Episode: 308, Action: 2, Reward: 1, Done: True
# Episode: 309, Action: 2, Reward: 1, Done: True
# Episode: 310, Action: 2, Reward: 1, Done: True
# Episode: 311, Action: 2, Reward: 1, Done: True
# Episode: 312, Action: 2, Reward: -1, Done: True
# Episode: 313, Action: 2, Reward: 1, Done: True
# Episode: 314, Action: 2, Reward: 1, Done: True
# Episode: 315, Action: 2, Reward: 1, Done: True
# Episode: 316, Action: 2, Reward: 1, Done: True
# Episode: 317, Action: 2, Reward: 1, Done: True
# Episode: 318, Action: 2, Reward: 1, Done: True
# Episode: 319, Action: 2, Reward: 1, Done: True
# Episode: 320, Action: 2, Reward: 1, Done: True
# Episode: 321, Action: 2, Reward: 1, Done: True
# Episode: 322, Action: 2, Reward: 1, Done: True
# Episode: 323, Action: 2, Reward: 1, Done: True
# Episode: 324, Action: 2, Reward: 1, Done: True
# Episode: 325, Action: 2, Reward: 1, Done: True
# Episode: 326, Action: 2, Reward: 1, Done: True
# Episode: 327, Action: 2, Reward: 1, Done: True
# Episode: 328, Action: 2, Reward: 1, Done: True
# Episode: 329, Action: 3, Reward: 1, Done: True
# Episode: 330, Action: 2, Reward: 1, Done: True
# Episode: 331, Action: 2, Reward: 1, Done: True
# Episode: 332, Action: 2, Reward: 1, Done: True
# Episode: 333, Action: 2, Reward: 1, Done: True
# Episode: 334, Action: 1, Reward: -1, Done: True
# Episode: 335, Action: 2, Reward: 1, Done: True
# Episode: 336, Action: 2, Reward: -1, Done: True
# Episode: 337, Action: 2, Reward: 1, Done: True
# Episode: 338, Action: 2, Reward: 1, Done: True
# Episode: 339, Action: 2, Reward: 1, Done: True
# Episode: 340, Action: 2, Reward: 1, Done: True
# Episode: 341, Action: 2, Reward: 1, Done: True
# Episode: 342, Action: 3, Reward: 1, Done: True
# Episode: 343, Action: 2, Reward: 1, Done: True
# Episode: 344, Action: 2, Reward: 1, Done: True
# Episode: 345, Action: 2, Reward: 1, Done: True
# Episode: 346, Action: 2, Reward: 1, Done: True
# Episode: 347, Action: 2, Reward: 1, Done: True
# Episode: 348, Action: 2, Reward: 1, Done: True
# Episode: 349, Action: 2, Reward: 1, Done: True
# Episode: 350, Action: 2, Reward: 1, Done: True
# Episode: 351, Action: 2, Reward: 1, Done: True
# Episode: 352, Action: 2, Reward: 1, Done: True
# Episode: 353, Action: 2, Reward: 1, Done: True
# Episode: 354, Action: 2, Reward: 1, Done: True
# Episode: 355, Action: 2, Reward: -1, Done: True
# Episode: 356, Action: 2, Reward: 1, Done: True
# Episode: 357, Action: 2, Reward: 1, Done: True
# Episode: 358, Action: 2, Reward: 1, Done: True
# Episode: 359, Action: 2, Reward: 1, Done: True
# Episode: 360, Action: 2, Reward: 1, Done: True
# Episode: 361, Action: 3, Reward: 1, Done: True
# Episode: 362, Action: 2, Reward: 1, Done: True
# Episode: 363, Action: 2, Reward: 1, Done: True
# Episode: 364, Action: 2, Reward: 1, Done: True
# Episode: 365, Action: 2, Reward: 1, Done: True
# Episode: 366, Action: 2, Reward: 1, Done: True
# Episode: 367, Action: 2, Reward: 1, Done: True
# Episode: 368, Action: 2, Reward: 1, Done: True
# Episode: 369, Action: 2, Reward: 1, Done: True
# Episode: 370, Action: 2, Reward: 1, Done: True
# Episode: 371, Action: 2, Reward: 1, Done: True
# Episode: 372, Action: 2, Reward: 1, Done: True
# Episode: 373, Action: 2, Reward: 1, Done: True
# Episode: 374, Action: 2, Reward: 1, Done: True
# Episode: 375, Action: 2, Reward: 1, Done: True
# Episode: 376, Action: 2, Reward: 1, Done: True
# Episode: 377, Action: 2, Reward: 1, Done: True
# Episode: 378, Action: 3, Reward: 1, Done: True
# Episode: 379, Action: 2, Reward: 1, Done: True
# Episode: 380, Action: 2, Reward: 1, Done: True
# Episode: 381, Action: 2, Reward: 1, Done: True
# Episode: 382, Action: 2, Reward: 1, Done: True
# Episode: 383, Action: 2, Reward: 1, Done: True
# Episode: 384, Action: 2, Reward: 1, Done: True
# Episode: 385, Action: 2, Reward: 1, Done: True
# Episode: 386, Action: 2, Reward: 1, Done: True
# Episode: 387, Action: 2, Reward: 1, Done: True
# Episode: 388, Action: 2, Reward: 1, Done: True
# Episode: 389, Action: 2, Reward: 1, Done: True
# Episode: 390, Action: 2, Reward: 1, Done: True
# Episode: 391, Action: 2, Reward: 1, Done: True
# Episode: 392, Action: 2, Reward: 1, Done: True
# Episode: 393, Action: 2, Reward: 1, Done: True
# Episode: 394, Action: 2, Reward: 1, Done: True
# Episode: 395, Action: 2, Reward: 1, Done: True
# Episode: 396, Action: 2, Reward: 1, Done: True
# Episode: 397, Action: 2, Reward: 1, Done: True
# Episode: 398, Action: 3, Reward: 1, Done: True
# Episode: 399, Action: 2, Reward: 1, Done: True
# Episode: 400, Action: 2, Reward: 1, Done: True
# Episode: 401, Action: 2, Reward: 1, Done: True
# Episode: 402, Action: 2, Reward: 1, Done: True
# Episode: 403, Action: 2, Reward: 1, Done: True
# Episode: 404, Action: 2, Reward: 1, Done: True
# Episode: 405, Action: 2, Reward: 1, Done: True
# Episode: 406, Action: 2, Reward: 1, Done: True
# Episode: 407, Action: 2, Reward: 1, Done: True
# Episode: 408, Action: 2, Reward: 1, Done: True
# Episode: 409, Action: 3, Reward: 1, Done: True
# Episode: 410, Action: 2, Reward: 1, Done: True
# Episode: 411, Action: 2, Reward: 1, Done: True
# Episode: 412, Action: 2, Reward: 1, Done: True
# Episode: 413, Action: 2, Reward: 1, Done: True
# Episode: 414, Action: 2, Reward: 1, Done: True
# Episode: 415, Action: 2, Reward: 1, Done: True
# Episode: 416, Action: 2, Reward: 1, Done: True
# Episode: 417, Action: 2, Reward: 1, Done: True
# Episode: 418, Action: 2, Reward: 1, Done: True
# Episode: 419, Action: 2, Reward: 1, Done: True
# Episode: 420, Action: 2, Reward: 1, Done: True
# Episode: 421, Action: 2, Reward: 1, Done: True
# Episode: 422, Action: 2, Reward: 1, Done: True
# Episode: 423, Action: 2, Reward: 1, Done: True
# Episode: 424, Action: 3, Reward: 1, Done: True
# Episode: 425, Action: 2, Reward: 1, Done: True
# Episode: 426, Action: 2, Reward: 1, Done: True
# Episode: 427, Action: 2, Reward: 1, Done: True
# Episode: 428, Action: 2, Reward: 1, Done: True
# Episode: 429, Action: 2, Reward: 1, Done: True
# Episode: 430, Action: 2, Reward: 1, Done: True
# Episode: 431, Action: 2, Reward: 1, Done: True
# Episode: 432, Action: 2, Reward: 1, Done: True
# Episode: 433, Action: 2, Reward: 1, Done: True
# Episode: 434, Action: 2, Reward: 1, Done: True
# Episode: 435, Action: 2, Reward: 1, Done: True
# Episode: 436, Action: 2, Reward: 1, Done: True
# Episode: 437, Action: 2, Reward: 1, Done: True
# Episode: 438, Action: 2, Reward: 1, Done: True
# Episode: 439, Action: 3, Reward: 1, Done: True
# Episode: 440, Action: 2, Reward: 1, Done: True
# Episode: 441, Action: 2, Reward: 1, Done: True
# Episode: 442, Action: 2, Reward: 1, Done: True
# Episode: 443, Action: 2, Reward: 1, Done: True
# Episode: 444, Action: 2, Reward: 1, Done: True
# Episode: 445, Action: 2, Reward: 1, Done: True
# Episode: 446, Action: 2, Reward: 1, Done: True
# Episode: 447, Action: 2, Reward: 1, Done: True
# Episode: 448, Action: 2, Reward: 1, Done: True
# Episode: 449, Action: 1, Reward: -1, Done: True
# Episode: 450, Action: 2, Reward: 1, Done: True
# Episode: 451, Action: 2, Reward: 1, Done: True
# Episode: 452, Action: 2, Reward: 1, Done: True
# Episode: 453, Action: 2, Reward: 1, Done: True
# Episode: 454, Action: 2, Reward: 1, Done: True
# Episode: 455, Action: 2, Reward: 1, Done: True
# Episode: 456, Action: 2, Reward: 1, Done: True
# Episode: 457, Action: 2, Reward: 1, Done: True
# Episode: 458, Action: 2, Reward: 1, Done: True
# Episode: 459, Action: 2, Reward: 1, Done: True
# Episode: 460, Action: 3, Reward: 1, Done: True
# Episode: 461, Action: 2, Reward: 1, Done: True
# Episode: 462, Action: 2, Reward: 1, Done: True
# Episode: 463, Action: 2, Reward: 1, Done: True
# Episode: 464, Action: 2, Reward: 1, Done: True
# Episode: 465, Action: 2, Reward: 1, Done: True
# Episode: 466, Action: 2, Reward: 1, Done: True
# Episode: 467, Action: 3, Reward: 1, Done: True
# Episode: 468, Action: 2, Reward: 1, Done: True
# Episode: 469, Action: 2, Reward: 1, Done: True
# Episode: 470, Action: 2, Reward: 1, Done: True
# Episode: 471, Action: 2, Reward: 1, Done: True
# Episode: 472, Action: 2, Reward: 1, Done: True
# Episode: 473, Action: 2, Reward: 1, Done: True
# Episode: 474, Action: 2, Reward: 1, Done: True
# Episode: 475, Action: 2, Reward: 1, Done: True
# Episode: 476, Action: 2, Reward: 1, Done: True
# Episode: 477, Action: 2, Reward: 1, Done: True
# Episode: 478, Action: 2, Reward: 1, Done: True
# Episode: 479, Action: 2, Reward: 1, Done: True
# Episode: 480, Action: 2, Reward: 1, Done: True
# Episode: 481, Action: 2, Reward: 1, Done: True
# Episode: 482, Action: 2, Reward: 1, Done: True
# Episode: 483, Action: 2, Reward: 1, Done: True
# Episode: 484, Action: 2, Reward: 1, Done: True
# Episode: 485, Action: 3, Reward: 1, Done: True
# Episode: 486, Action: 2, Reward: 1, Done: True
# Episode: 487, Action: 2, Reward: 1, Done: True
# Episode: 488, Action: 2, Reward: 1, Done: True
# Episode: 489, Action: 2, Reward: 1, Done: True
# Episode: 490, Action: 2, Reward: 1, Done: True
# Episode: 491, Action: 2, Reward: 1, Done: True
# Episode: 492, Action: 2, Reward: 1, Done: True
# Episode: 493, Action: 2, Reward: 1, Done: True
# Episode: 494, Action: 2, Reward: 1, Done: True
# Episode: 495, Action: 2, Reward: 1, Done: True
# Episode: 496, Action: 2, Reward: 1, Done: True
# Episode: 497, Action: 2, Reward: 1, Done: True
# Episode: 498, Action: 2, Reward: 1, Done: True
# Episode: 499, Action: 2, Reward: 1, Done: True
# Episode: 500, Action: 3, Reward: 1, Done: True
# Episode: 501, Action: 2, Reward: 1, Done: True
# Episode: 502, Action: 2, Reward: 1, Done: True
# Episode: 503, Action: 2, Reward: 1, Done: True
# Episode: 504, Action: 3, Reward: 1, Done: True
# Episode: 505, Action: 0, Reward: -1, Done: True
# Episode: 506, Action: 2, Reward: 1, Done: True
# Episode: 507, Action: 2, Reward: 1, Done: True
# Episode: 508, Action: 2, Reward: 1, Done: True
# Episode: 509, Action: 2, Reward: 1, Done: True
# Episode: 510, Action: 2, Reward: 1, Done: True
# Episode: 511, Action: 2, Reward: 1, Done: True
# Episode: 512, Action: 2, Reward: 1, Done: True
# Episode: 513, Action: 2, Reward: 1, Done: True
# Episode: 514, Action: 2, Reward: 1, Done: True
# Episode: 515, Action: 2, Reward: 1, Done: True
# Episode: 516, Action: 3, Reward: 1, Done: True
# Episode: 517, Action: 2, Reward: 1, Done: True
# Episode: 518, Action: 2, Reward: 1, Done: True
# Episode: 519, Action: 2, Reward: 1, Done: True
# Episode: 520, Action: 2, Reward: 1, Done: True
# Episode: 521, Action: 2, Reward: 1, Done: True
# Episode: 522, Action: 2, Reward: 1, Done: True
# Episode: 523, Action: 2, Reward: 1, Done: True
# Episode: 524, Action: 2, Reward: 1, Done: True
# Episode: 525, Action: 2, Reward: 1, Done: True
# Episode: 526, Action: 2, Reward: 1, Done: True
# Episode: 527, Action: 2, Reward: 1, Done: True
# Episode: 528, Action: 2, Reward: 1, Done: True
# Episode: 529, Action: 2, Reward: 1, Done: True
# Episode: 530, Action: 2, Reward: 1, Done: True
# Episode: 531, Action: 2, Reward: 1, Done: True
# Episode: 532, Action: 2, Reward: 1, Done: True
# Episode: 533, Action: 2, Reward: 1, Done: True
# Episode: 534, Action: 2, Reward: 1, Done: True
# Episode: 535, Action: 2, Reward: 1, Done: True
# Episode: 536, Action: 3, Reward: 1, Done: True
# Episode: 537, Action: 2, Reward: 1, Done: True
# Episode: 538, Action: 2, Reward: 1, Done: True
# Episode: 539, Action: 2, Reward: 1, Done: True
# Episode: 540, Action: 2, Reward: 1, Done: True
# Episode: 541, Action: 2, Reward: 1, Done: True
# Episode: 542, Action: 3, Reward: 1, Done: True
# Episode: 543, Action: 2, Reward: 1, Done: True
# Episode: 544, Action: 2, Reward: 1, Done: True
# Episode: 545, Action: 2, Reward: 1, Done: True
# Episode: 546, Action: 2, Reward: 1, Done: True
# Episode: 547, Action: 2, Reward: 1, Done: True
# Episode: 548, Action: 2, Reward: 1, Done: True
# Episode: 549, Action: 2, Reward: 1, Done: True
# Episode: 550, Action: 2, Reward: 1, Done: True
# Episode: 551, Action: 2, Reward: 1, Done: True
# Episode: 552, Action: 3, Reward: 1, Done: True
# Episode: 553, Action: 2, Reward: 1, Done: True
# Episode: 554, Action: 2, Reward: 1, Done: True
# Episode: 555, Action: 2, Reward: 1, Done: True
# Episode: 556, Action: 3, Reward: 1, Done: True
# Episode: 557, Action: 2, Reward: 1, Done: True
# Episode: 558, Action: 2, Reward: 1, Done: True
# Episode: 559, Action: 2, Reward: 1, Done: True
# Episode: 560, Action: 2, Reward: 1, Done: True
# Episode: 561, Action: 3, Reward: 1, Done: True
# Episode: 562, Action: 2, Reward: 1, Done: True
# Episode: 563, Action: 2, Reward: 1, Done: True
# Episode: 564, Action: 2, Reward: 1, Done: True
# Episode: 565, Action: 2, Reward: 1, Done: True
# Episode: 566, Action: 2, Reward: 1, Done: True
# Episode: 567, Action: 2, Reward: 1, Done: True
# Episode: 568, Action: 2, Reward: 1, Done: True
# Episode: 569, Action: 3, Reward: 1, Done: True
# Episode: 570, Action: 2, Reward: 1, Done: True
# Episode: 571, Action: 2, Reward: 1, Done: True
# Episode: 572, Action: 2, Reward: 1, Done: True
# Episode: 573, Action: 2, Reward: 1, Done: True
# Episode: 574, Action: 2, Reward: 1, Done: True
# Episode: 575, Action: 2, Reward: 1, Done: True
# Episode: 576, Action: 2, Reward: 1, Done: True
# Episode: 577, Action: 3, Reward: 1, Done: True
# Episode: 578, Action: 2, Reward: 1, Done: True
# Episode: 579, Action: 2, Reward: 1, Done: True
# Episode: 580, Action: 2, Reward: 1, Done: True
# Episode: 581, Action: 2, Reward: 1, Done: True
# Episode: 582, Action: 2, Reward: 1, Done: True
# Episode: 583, Action: 2, Reward: 1, Done: True
# Episode: 584, Action: 2, Reward: 1, Done: True
# Episode: 585, Action: 3, Reward: 1, Done: True
# Episode: 586, Action: 3, Reward: 1, Done: True
# Episode: 587, Action: 2, Reward: 1, Done: True
# Episode: 588, Action: 2, Reward: 1, Done: True
# Episode: 589, Action: 2, Reward: 1, Done: True
# Episode: 590, Action: 2, Reward: 1, Done: True
# Episode: 591, Action: 2, Reward: 1, Done: True
# Episode: 592, Action: 2, Reward: 1, Done: True
# Episode: 593, Action: 2, Reward: 1, Done: True
# Episode: 594, Action: 2, Reward: 1, Done: True
# Episode: 595, Action: 2, Reward: 1, Done: True
# Episode: 596, Action: 2, Reward: 1, Done: True
# Episode: 597, Action: 3, Reward: 1, Done: True
# Episode: 598, Action: 2, Reward: 1, Done: True
# Episode: 599, Action: 2, Reward: 1, Done: True
# Episode: 600, Action: 2, Reward: 1, Done: True
# Episode: 601, Action: 2, Reward: 1, Done: True
# Episode: 602, Action: 2, Reward: 1, Done: True
# Episode: 603, Action: 2, Reward: 1, Done: True
# Episode: 604, Action: 2, Reward: 1, Done: True
# Episode: 605, Action: 2, Reward: 1, Done: True
# Episode: 606, Action: 2, Reward: 1, Done: True
# Episode: 607, Action: 2, Reward: 1, Done: True
# Episode: 608, Action: 2, Reward: 1, Done: True
# Episode: 609, Action: 2, Reward: 1, Done: True
# Episode: 610, Action: 2, Reward: 1, Done: True
# Episode: 611, Action: 2, Reward: 1, Done: True
# Episode: 612, Action: 2, Reward: 1, Done: True
# Episode: 613, Action: 2, Reward: 1, Done: True
# Episode: 614, Action: 3, Reward: 1, Done: True
# Episode: 615, Action: 3, Reward: 1, Done: True
# Episode: 616, Action: 2, Reward: 1, Done: True
# Episode: 617, Action: 3, Reward: 1, Done: True
# Episode: 618, Action: 2, Reward: 1, Done: True
# Episode: 619, Action: 2, Reward: 1, Done: True
# Episode: 620, Action: 2, Reward: 1, Done: True
# Episode: 621, Action: 3, Reward: 1, Done: True
# Episode: 622, Action: 2, Reward: 1, Done: True
# Episode: 623, Action: 2, Reward: 1, Done: True
# Episode: 624, Action: 2, Reward: 1, Done: True
# Episode: 625, Action: 2, Reward: 1, Done: True
# Episode: 626, Action: 2, Reward: 1, Done: True
# Episode: 627, Action: 2, Reward: 1, Done: True
# Episode: 628, Action: 2, Reward: 1, Done: True
# Episode: 629, Action: 2, Reward: 1, Done: True
# Episode: 630, Action: 2, Reward: 1, Done: True
# Episode: 631, Action: 2, Reward: 1, Done: True
# Episode: 632, Action: 2, Reward: 1, Done: True
# Episode: 633, Action: 2, Reward: 1, Done: True
# Episode: 634, Action: 2, Reward: 1, Done: True
# Episode: 635, Action: 2, Reward: 1, Done: True
# Episode: 636, Action: 2, Reward: 1, Done: True
# Episode: 637, Action: 2, Reward: 1, Done: True
# Episode: 638, Action: 2, Reward: 1, Done: True
# Episode: 639, Action: 2, Reward: 1, Done: True
# Episode: 640, Action: 2, Reward: 1, Done: True
# Episode: 641, Action: 2, Reward: 1, Done: True
# Episode: 642, Action: 3, Reward: 1, Done: True
# Episode: 643, Action: 2, Reward: 1, Done: True
# Episode: 644, Action: 2, Reward: 1, Done: True
# Episode: 645, Action: 2, Reward: 1, Done: True
# Episode: 646, Action: 2, Reward: 1, Done: True
# Episode: 647, Action: 2, Reward: 1, Done: True
# Episode: 648, Action: 2, Reward: 1, Done: True
# Episode: 649, Action: 3, Reward: 1, Done: True
# Episode: 650, Action: 2, Reward: 1, Done: True
# Episode: 651, Action: 2, Reward: 1, Done: True
# Episode: 652, Action: 2, Reward: 1, Done: True
# Episode: 653, Action: 2, Reward: 1, Done: True
# Episode: 654, Action: 2, Reward: 1, Done: True
# Episode: 655, Action: 3, Reward: 1, Done: True
# Episode: 656, Action: 3, Reward: 1, Done: True
# Episode: 657, Action: 2, Reward: 1, Done: True
# Episode: 658, Action: 2, Reward: 1, Done: True
# Episode: 659, Action: 2, Reward: 1, Done: True
# Episode: 660, Action: 2, Reward: 1, Done: True
# Episode: 661, Action: 1, Reward: -1, Done: True
# Episode: 662, Action: 2, Reward: 1, Done: True
# Episode: 663, Action: 2, Reward: 1, Done: True
# Episode: 664, Action: 2, Reward: 1, Done: True
# Episode: 665, Action: 2, Reward: 1, Done: True
# Episode: 666, Action: 3, Reward: 1, Done: True
# Episode: 667, Action: 2, Reward: 1, Done: True
# Episode: 668, Action: 3, Reward: -1, Done: True
# Episode: 669, Action: 3, Reward: 1, Done: True
# Episode: 670, Action: 2, Reward: 1, Done: True
# Episode: 671, Action: 2, Reward: 1, Done: True
# Episode: 672, Action: 3, Reward: 1, Done: True
# Episode: 673, Action: 2, Reward: 1, Done: True
# Episode: 674, Action: 0, Reward: -1, Done: True
# Episode: 675, Action: 2, Reward: 1, Done: True
# Episode: 676, Action: 2, Reward: -1, Done: True
# Episode: 677, Action: 3, Reward: 1, Done: True
# Episode: 678, Action: 2, Reward: 1, Done: True
# Episode: 679, Action: 2, Reward: 1, Done: True
# Episode: 680, Action: 2, Reward: 1, Done: True
# Episode: 681, Action: 3, Reward: 1, Done: True
# Episode: 682, Action: 2, Reward: 1, Done: True
# Episode: 683, Action: 2, Reward: 1, Done: True
# Episode: 684, Action: 2, Reward: 1, Done: True
# Episode: 685, Action: 2, Reward: 1, Done: True
# Episode: 686, Action: 2, Reward: 1, Done: True
# Episode: 687, Action: 0, Reward: -1, Done: True
# Episode: 688, Action: 3, Reward: -1, Done: True
# Episode: 689, Action: 3, Reward: 1, Done: True
# Episode: 690, Action: 2, Reward: 1, Done: True
# Episode: 691, Action: 2, Reward: 1, Done: True
# Episode: 692, Action: 2, Reward: 1, Done: True
# Episode: 693, Action: 2, Reward: 1, Done: True
# Episode: 694, Action: 2, Reward: 1, Done: True
# Episode: 695, Action: 2, Reward: 1, Done: True
# Episode: 696, Action: 0, Reward: -1, Done: True
# Episode: 697, Action: 2, Reward: -1, Done: True
# Episode: 698, Action: 2, Reward: 1, Done: True
# Episode: 699, Action: 2, Reward: 1, Done: True
# Episode: 700, Action: 2, Reward: 1, Done: True
# Episode: 701, Action: 2, Reward: 1, Done: True
# Episode: 702, Action: 2, Reward: 1, Done: True
# Episode: 703, Action: 2, Reward: 1, Done: True
# Episode: 704, Action: 2, Reward: 1, Done: True
# Episode: 705, Action: 2, Reward: 1, Done: True
# Episode: 706, Action: 2, Reward: 1, Done: True
# Episode: 707, Action: 0, Reward: -1, Done: True
# Episode: 708, Action: 2, Reward: -1, Done: True
# Episode: 709, Action: 3, Reward: 1, Done: True
# Episode: 710, Action: 2, Reward: 1, Done: True
# Episode: 711, Action: 2, Reward: 1, Done: True
# Episode: 712, Action: 2, Reward: 1, Done: True
# Episode: 713, Action: 2, Reward: -1, Done: True
# Episode: 714, Action: 0, Reward: -1, Done: True
# Episode: 715, Action: 2, Reward: 1, Done: True
# Episode: 716, Action: 2, Reward: 1, Done: True
# Episode: 717, Action: 2, Reward: 1, Done: True
# Episode: 718, Action: 2, Reward: 1, Done: True
# Episode: 719, Action: 3, Reward: -1, Done: True
# Episode: 720, Action: 2, Reward: 1, Done: True
# Episode: 721, Action: 3, Reward: 1, Done: True
# Episode: 722, Action: 3, Reward: 1, Done: True
# Episode: 723, Action: 2, Reward: -1, Done: True
# Episode: 724, Action: 3, Reward: 1, Done: True
# Episode: 725, Action: 2, Reward: 1, Done: True
# Episode: 726, Action: 2, Reward: 1, Done: True
# Episode: 727, Action: 2, Reward: 1, Done: True
# Episode: 728, Action: 3, Reward: 1, Done: True
# Episode: 729, Action: 2, Reward: -1, Done: True
# Episode: 730, Action: 3, Reward: 1, Done: True
# Episode: 731, Action: 2, Reward: 1, Done: True
# Episode: 732, Action: 2, Reward: 1, Done: True
# Episode: 733, Action: 2, Reward: 1, Done: True
# Episode: 734, Action: 2, Reward: 1, Done: True
# Episode: 735, Action: 2, Reward: 1, Done: True
# Episode: 736, Action: 2, Reward: 1, Done: True
# Episode: 737, Action: 2, Reward: 1, Done: True
# Episode: 738, Action: 3, Reward: 1, Done: True
# Episode: 739, Action: 2, Reward: 1, Done: True
# Episode: 740, Action: 2, Reward: 1, Done: True
# Episode: 741, Action: 3, Reward: 1, Done: True
# Episode: 742, Action: 2, Reward: 1, Done: True
# Episode: 743, Action: 2, Reward: 1, Done: True
# Episode: 744, Action: 2, Reward: 1, Done: True
# Episode: 745, Action: 2, Reward: 1, Done: True
# Episode: 746, Action: 2, Reward: -1, Done: True
# Episode: 747, Action: 2, Reward: 1, Done: True
# Episode: 748, Action: 0, Reward: -1, Done: True
# Episode: 749, Action: 3, Reward: 1, Done: True
# Episode: 750, Action: 2, Reward: 1, Done: True
# Episode: 751, Action: 2, Reward: 1, Done: True
# Episode: 752, Action: 2, Reward: 1, Done: True
# Episode: 753, Action: 2, Reward: 1, Done: True
# Episode: 754, Action: 2, Reward: 1, Done: True
# Episode: 755, Action: 0, Reward: -1, Done: True
# Episode: 756, Action: 2, Reward: 1, Done: True
# Episode: 757, Action: 2, Reward: 1, Done: True
# Episode: 758, Action: 2, Reward: 1, Done: True
# Episode: 759, Action: 2, Reward: 1, Done: True
# Episode: 760, Action: 2, Reward: -1, Done: True
# Episode: 761, Action: 2, Reward: 1, Done: True
# Episode: 762, Action: 2, Reward: 1, Done: True
# Episode: 763, Action: 2, Reward: 1, Done: True
# Episode: 764, Action: 0, Reward: -1, Done: True
# Episode: 765, Action: 2, Reward: 1, Done: True
# Episode: 766, Action: 0, Reward: -1, Done: True
# Episode: 767, Action: 2, Reward: 1, Done: True
# Episode: 768, Action: 1, Reward: -1, Done: True
# Episode: 769, Action: 2, Reward: -1, Done: True
# Episode: 770, Action: 2, Reward: 1, Done: True
# Episode: 771, Action: 2, Reward: 1, Done: True
# Episode: 772, Action: 2, Reward: 1, Done: True
# Episode: 773, Action: 1, Reward: -1, Done: True
# Episode: 774, Action: 2, Reward: 1, Done: True
# Episode: 775, Action: 2, Reward: 1, Done: True
# Episode: 776, Action: 2, Reward: 1, Done: True
# Episode: 777, Action: 2, Reward: 1, Done: True
# Episode: 778, Action: 1, Reward: -1, Done: True
# Episode: 779, Action: 0, Reward: -1, Done: True
# Episode: 780, Action: 2, Reward: 1, Done: True
# Episode: 781, Action: 1, Reward: -1, Done: True
# Episode: 782, Action: 3, Reward: 1, Done: True
# Episode: 783, Action: 3, Reward: -1, Done: True
# Episode: 784, Action: 2, Reward: 1, Done: True
# Episode: 785, Action: 2, Reward: 1, Done: True
# Episode: 786, Action: 3, Reward: -1, Done: True
# Episode: 787, Action: 2, Reward: 1, Done: True
# Episode: 788, Action: 3, Reward: 1, Done: True
# Episode: 789, Action: 0, Reward: -1, Done: True
# Episode: 790, Action: 3, Reward: 1, Done: True
# Episode: 791, Action: 2, Reward: 1, Done: True
# Episode: 792, Action: 2, Reward: 1, Done: True
# Episode: 793, Action: 2, Reward: 1, Done: True
# Episode: 794, Action: 0, Reward: -1, Done: True
# Episode: 795, Action: 0, Reward: -1, Done: True
# Episode: 796, Action: 1, Reward: -1, Done: True
# Episode: 797, Action: 2, Reward: 1, Done: True
# Episode: 798, Action: 2, Reward: -1, Done: True
# Episode: 799, Action: 2, Reward: 1, Done: True
# Episode: 800, Action: 3, Reward: 1, Done: True
# Episode: 801, Action: 2, Reward: 1, Done: True
# Episode: 802, Action: 2, Reward: 1, Done: True
# Episode: 803, Action: 2, Reward: -1, Done: True
# Episode: 804, Action: 0, Reward: -1, Done: True
# Episode: 805, Action: 2, Reward: 1, Done: True
# Episode: 806, Action: 2, Reward: 1, Done: True
# Episode: 807, Action: 3, Reward: -1, Done: True
# Episode: 808, Action: 2, Reward: 1, Done: True
# Episode: 809, Action: 1, Reward: -1, Done: True
# Episode: 810, Action: 2, Reward: 1, Done: True
# Episode: 811, Action: 2, Reward: 1, Done: True
# Episode: 812, Action: 2, Reward: 1, Done: True
# Episode: 813, Action: 1, Reward: -1, Done: True
# Episode: 814, Action: 1, Reward: -1, Done: True
# Episode: 815, Action: 2, Reward: 1, Done: True
# Episode: 816, Action: 2, Reward: 1, Done: True
# Episode: 817, Action: 0, Reward: -1, Done: True
# Episode: 818, Action: 2, Reward: 1, Done: True
# Episode: 819, Action: 2, Reward: 1, Done: True
# Episode: 820, Action: 3, Reward: 1, Done: True
# Episode: 821, Action: 3, Reward: -1, Done: True
# Episode: 822, Action: 2, Reward: 1, Done: True
# Episode: 823, Action: 2, Reward: 1, Done: True
# Episode: 824, Action: 2, Reward: -1, Done: True
# Episode: 825, Action: 3, Reward: 1, Done: True
# Episode: 826, Action: 0, Reward: -1, Done: True
# Episode: 827, Action: 1, Reward: -1, Done: True
# Episode: 828, Action: 1, Reward: -1, Done: True
# Episode: 829, Action: 2, Reward: 1, Done: True
# Episode: 830, Action: 1, Reward: -1, Done: True
# Episode: 831, Action: 1, Reward: -1, Done: True
# Episode: 832, Action: 1, Reward: -1, Done: True
# Episode: 833, Action: 2, Reward: -1, Done: True
# Episode: 834, Action: 3, Reward: 1, Done: True
# Episode: 835, Action: 2, Reward: 1, Done: True
# Episode: 836, Action: 1, Reward: -1, Done: True
# Episode: 837, Action: 3, Reward: -1, Done: True
# Episode: 838, Action: 2, Reward: 1, Done: True
# Episode: 839, Action: 2, Reward: 1, Done: True
# Episode: 840, Action: 2, Reward: 1, Done: True
# Episode: 841, Action: 3, Reward: 1, Done: True
# Episode: 842, Action: 1, Reward: -1, Done: True
# Episode: 843, Action: 2, Reward: 1, Done: True
# Episode: 844, Action: 3, Reward: 1, Done: True
# Episode: 845, Action: 2, Reward: 1, Done: True
# Episode: 846, Action: 2, Reward: 1, Done: True
# Episode: 847, Action: 2, Reward: 1, Done: True
# Episode: 848, Action: 0, Reward: -1, Done: True
# Episode: 849, Action: 2, Reward: -1, Done: True
# Episode: 850, Action: 2, Reward: 1, Done: True
# Episode: 851, Action: 1, Reward: -1, Done: True
# Episode: 852, Action: 2, Reward: -1, Done: True
# Episode: 853, Action: 0, Reward: -1, Done: True
# Episode: 854, Action: 3, Reward: 1, Done: True
# Episode: 855, Action: 3, Reward: 1, Done: True
# Episode: 856, Action: 3, Reward: 1, Done: True
# Episode: 857, Action: 2, Reward: 1, Done: True
# Episode: 858, Action: 2, Reward: 1, Done: True
# Episode: 859, Action: 2, Reward: 1, Done: True
# Episode: 860, Action: 2, Reward: 1, Done: True
# Episode: 861, Action: 2, Reward: 1, Done: True
# Episode: 862, Action: 2, Reward: 1, Done: True
# Episode: 863, Action: 2, Reward: 1, Done: True
# Episode: 864, Action: 2, Reward: 1, Done: True
# Episode: 865, Action: 2, Reward: 1, Done: True
# Episode: 866, Action: 3, Reward: -1, Done: True
# Episode: 867, Action: 2, Reward: 1, Done: True
# Episode: 868, Action: 3, Reward: 1, Done: True
# Episode: 869, Action: 2, Reward: 1, Done: True
# Episode: 870, Action: 0, Reward: -1, Done: True
# Episode: 871, Action: 0, Reward: -1, Done: True
# Episode: 872, Action: 2, Reward: 1, Done: True
# Episode: 873, Action: 1, Reward: -1, Done: True
# Episode: 874, Action: 3, Reward: 1, Done: True
# Episode: 875, Action: 2, Reward: 1, Done: True
# Episode: 876, Action: 1, Reward: -1, Done: True
# Episode: 877, Action: 3, Reward: 1, Done: True
# Episode: 878, Action: 2, Reward: 1, Done: True
# Episode: 879, Action: 1, Reward: -1, Done: True
# Episode: 880, Action: 2, Reward: 1, Done: True
# Episode: 881, Action: 2, Reward: 1, Done: True
# Episode: 882, Action: 2, Reward: 1, Done: True
# Episode: 883, Action: 2, Reward: 1, Done: True
# Episode: 884, Action: 1, Reward: -1, Done: True
# Episode: 885, Action: 1, Reward: -1, Done: True
# Episode: 886, Action: 2, Reward: 1, Done: True
# Episode: 887, Action: 2, Reward: 1, Done: True
# Episode: 888, Action: 2, Reward: 1, Done: True
# Episode: 889, Action: 2, Reward: 1, Done: True
# Episode: 890, Action: 3, Reward: 1, Done: True
# Episode: 891, Action: 2, Reward: 1, Done: True
# Episode: 892, Action: 2, Reward: 1, Done: True
# Episode: 893, Action: 3, Reward: 1, Done: True
# Episode: 894, Action: 2, Reward: 1, Done: True
# Episode: 895, Action: 2, Reward: 1, Done: True
# Episode: 896, Action: 1, Reward: -1, Done: True
# Episode: 897, Action: 2, Reward: 1, Done: True
# Episode: 898, Action: 0, Reward: -1, Done: True
# Episode: 899, Action: 2, Reward: 1, Done: True
# Episode: 900, Action: 2, Reward: 1, Done: True
# Episode: 901, Action: 2, Reward: -1, Done: True
# Episode: 902, Action: 3, Reward: 1, Done: True
# Episode: 903, Action: 2, Reward: 1, Done: True
# Episode: 904, Action: 2, Reward: -1, Done: True
# Episode: 905, Action: 2, Reward: 1, Done: True
# Episode: 906, Action: 2, Reward: 1, Done: True
# Episode: 907, Action: 1, Reward: -1, Done: True
# Episode: 908, Action: 2, Reward: 1, Done: True
# Episode: 909, Action: 1, Reward: -1, Done: True
# Episode: 910, Action: 2, Reward: 1, Done: True
# Episode: 911, Action: 1, Reward: -1, Done: True
# Episode: 912, Action: 2, Reward: -1, Done: True
# Episode: 913, Action: 2, Reward: 1, Done: True
# Episode: 914, Action: 2, Reward: 1, Done: True
# Episode: 915, Action: 2, Reward: 1, Done: True
# Episode: 916, Action: 2, Reward: 1, Done: True
# Episode: 917, Action: 3, Reward: 1, Done: True
# Episode: 918, Action: 2, Reward: 1, Done: True
# Episode: 919, Action: 2, Reward: 1, Done: True
# Episode: 920, Action: 2, Reward: 1, Done: True
# Episode: 921, Action: 2, Reward: 1, Done: True
# Episode: 922, Action: 2, Reward: 1, Done: True
# Episode: 923, Action: 2, Reward: 1, Done: True
# Episode: 924, Action: 2, Reward: 1, Done: True
# Episode: 925, Action: 2, Reward: 1, Done: True
# Episode: 926, Action: 2, Reward: 1, Done: True
# Episode: 927, Action: 2, Reward: 1, Done: True
# Episode: 928, Action: 2, Reward: 1, Done: True
# Episode: 929, Action: 2, Reward: 1, Done: True
# Episode: 930, Action: 2, Reward: 1, Done: True
# Episode: 931, Action: 2, Reward: 1, Done: True
# Episode: 932, Action: 2, Reward: -1, Done: True
# Episode: 933, Action: 2, Reward: 1, Done: True
# Episode: 934, Action: 2, Reward: 1, Done: True
# Episode: 935, Action: 2, Reward: 1, Done: True
# Episode: 936, Action: 3, Reward: -1, Done: True
# Episode: 937, Action: 2, Reward: 1, Done: True
# Episode: 938, Action: 2, Reward: 1, Done: True
# Episode: 939, Action: 3, Reward: -1, Done: True
# Episode: 940, Action: 3, Reward: 1, Done: True
# Episode: 941, Action: 2, Reward: 1, Done: True
# Episode: 942, Action: 2, Reward: 1, Done: True
# Episode: 943, Action: 2, Reward: 1, Done: True
# Episode: 944, Action: 2, Reward: -1, Done: True
# Episode: 945, Action: 1, Reward: -1, Done: True
# Episode: 946, Action: 2, Reward: 1, Done: True
# Episode: 947, Action: 2, Reward: 1, Done: True
# Episode: 948, Action: 3, Reward: 1, Done: True
# Episode: 949, Action: 2, Reward: 1, Done: True
# Episode: 950, Action: 2, Reward: 1, Done: True
# Episode: 951, Action: 2, Reward: 1, Done: True
# Episode: 952, Action: 2, Reward: 1, Done: True
# Episode: 953, Action: 2, Reward: 1, Done: True
# Episode: 954, Action: 2, Reward: 1, Done: True
# Episode: 955, Action: 2, Reward: 1, Done: True
# Episode: 956, Action: 2, Reward: 1, Done: True
# Episode: 957, Action: 1, Reward: -1, Done: True
# Episode: 958, Action: 2, Reward: 1, Done: True
# Episode: 959, Action: 2, Reward: 1, Done: True
# Episode: 960, Action: 2, Reward: 1, Done: True
# Episode: 961, Action: 2, Reward: 1, Done: True
# Episode: 962, Action: 3, Reward: 1, Done: True
# Episode: 963, Action: 2, Reward: 1, Done: True
# Episode: 964, Action: 2, Reward: 1, Done: True
# Episode: 965, Action: 2, Reward: 1, Done: True
# Episode: 966, Action: 2, Reward: 1, Done: True
# Episode: 967, Action: 2, Reward: 1, Done: True
# Episode: 968, Action: 3, Reward: -1, Done: True
# Episode: 969, Action: 1, Reward: -1, Done: True
# Episode: 970, Action: 1, Reward: -1, Done: True
# Episode: 971, Action: 2, Reward: 1, Done: True
# Episode: 972, Action: 2, Reward: 1, Done: True
# Episode: 973, Action: 2, Reward: 1, Done: True
# Episode: 974, Action: 2, Reward: 1, Done: True
# Episode: 975, Action: 3, Reward: -1, Done: True
# Episode: 976, Action: 0, Reward: -1, Done: True
# Episode: 977, Action: 2, Reward: 1, Done: True
# Episode: 978, Action: 2, Reward: 1, Done: True
# Episode: 979, Action: 2, Reward: 1, Done: True
# Episode: 980, Action: 3, Reward: 1, Done: True
# Episode: 981, Action: 2, Reward: 1, Done: True
# Episode: 982, Action: 2, Reward: 1, Done: True
# Episode: 983, Action: 2, Reward: 1, Done: True
# Episode: 984, Action: 1, Reward: -1, Done: True
# Episode: 985, Action: 3, Reward: -1, Done: True
# Episode: 986, Action: 2, Reward: 1, Done: True
# Episode: 987, Action: 2, Reward: 1, Done: True
# Episode: 988, Action: 3, Reward: -1, Done: True
# Episode: 989, Action: 1, Reward: -1, Done: True
# Episode: 990, Action: 2, Reward: 1, Done: True
# Episode: 991, Action: 1, Reward: -1, Done: True
# Episode: 992, Action: 2, Reward: -1, Done: True
# Episode: 993, Action: 2, Reward: 1, Done: True
# Episode: 994, Action: 3, Reward: -1, Done: True
# Episode: 995, Action: 2, Reward: 1, Done: True
# Episode: 996, Action: 2, Reward: 1, Done: True
# Episode: 997, Action: 1, Reward: -1, Done: True
# Episode: 998, Action: 2, Reward: 1, Done: True
# Episode: 999, Action: 2, Reward: 1, Done: True

# %% [markdown]
#  ## 3. Play with parameters and analyse results
#
# Finally, you will describe, evaluate, and interpret the results obtained from the two RL agents. Additionally, compare your agents with the provided Random Agent. Feel free to utilize the provided helper functions for evaluating your agents. Some important points are:
#
# - Both quantified evaluation and human evaluation are needed in the report. The quantified evaluation should focus on the measurement of reward. In the human evaluation, you can use the provided visual tools to interpret your results. Your report should include at least one plot presenting comparable measures for the different agents.
#
# - While evaluating the results of Agent 2 (with SARSA algorithm), please try at least 2 different values of **epsilon** (expect 0) and discuss the influence of different epsilon values on the results. In the end, please identify a reasonable epsilon value that could balance the exploration and exploitation, then fix this value for comparing the two agents. Present your trails and results in the report.
#
# - In the report, you also need to parcitularly describe and discuss the similarity and difference of results from two RL agents (hint: on-policy VS off-policy). For this, please make sure that the compared results are obtained from the same environment (the same maze for two different agents). Also, while evaluating the results of two agents, please try at least 2 different values of **gamma**. In this way, you could discuss the influence of this discount factor in your report.
#
# - Please run the simulation multiple times and average the results for all your findings.

# %%
# TODO: evaluation

# %% [markdown]
# # Bonus Tasks
#
# We would like to challenge you with the following bonus task. For each task that is successfully completed, you may obtain max. 1 extra point.
#
# 1. Implement a third RL agent using another RL algorithm (e.g. Monte Carlo methods, Expected SARSA or even neural network-based ones) and discuss your findings. Compare this third agent with the above ones and explain why this is a better (or worse) RL algorithm. You are allowed to reuse exsiting packages, but please cite them, test them in advance, and make sure that you can explain the used algorithm using your own words.
#
# 2. Can you explore and show other evaluation results? If so, implement and present one extra result (e.g. a plot). And please explain why it is a good evaluation method for our task or how it shows the difference between two RL agents/algorithms.
