# %% [markdown]
# # Assignment 4 – Robot in a maze

# %% [markdown]
# In the  fourth assignment, you will delve into the application of RL algorithms to address the real-world challenge of navigating a robot through a maze dubbed 'robot in a maze'. The primary objectives of this assignment include:
#
#  -   Formalizing a practical problem into a Markov Decision Process (MDP).
#  -   Gaining familiarity with the OpenAI Gym framework (recently renamed as Gymnasium) and utilizing it to implement RL agents.
#  -   Applying SARSA and Q-learning algorithms to solve the 'robot in a maze' MDP problem.
#  -   Evaluating the outcomes of the reinforcement learning process and interpreting your findings.
#  -   Reflecting on the distinctions between the two types of RL algorithms employed.
#
# By accomplishing these objectives, you will not only enhance your understanding of RL algorithms but also develop practical skills in formulating and solving complex problems in the context of autonomous navigation within a maze.
#
# In this assignment, you will be developing a robot to navigate its way through a maze. The project is divided into three parts (5 subtasks).
#
#   1. In the first part, you will familiarize yourself with the OpenAI Gym/Gymnasium framework.
#   2. In the second part, we have implemented the environment for you based on the Gym/Gymnasium framework. Your tasks include:
#      2.1. formalizing the problem as an MDP model,
#      2.2. implementing your own RL agents, and
#      2.3. training them to find the shortest route out of a maze.
#   3. Finally, in the third part, you will evaluate and interpret the results obtained from the implemented RL agents

# %% [markdown]
# ## 1. OpenAI gym
#
# Gym/Gymnasium (https://gymnasium.farama.org/) is a widely used standard toolkit for developing and comparing reinforcement learning algorithms. Gymnasium is the maintained fork of OpenAI’s Gym library (more on this recent change is available if you're interested: https://farama.org/Announcing-The-Farama-Foundation).
#
# Gym/Gymnasium makes no assumptions about the structure of your agent and is compatible with any machine learning library, such as TensorFlow or Theano.
#
# The library is a collection of test problems — environments — that you can use to develop your reinforcement learning algorithms. These environments have a shared interface, allowing you to write general algorithms.
#
# First, we download and install the Gym/Gymnasium library. Then, import the Gymnasium class.

# %%
#!pip install gymnasium

# %% [markdown]
# We are now going to explain how the RL framework of gym works.
# - An **ENVIRONMENT**,
# - You also have an **AGENT**,
# - In MDP problems, such as ours, the **ENVIRONMENT** provides an **OBSERVATION**, which represents the state of the **ENVIRONMENT** at the current moment.
# - The agent takes an **ACTION** based on its **OBSERVATION**,
# <!-- When a single **ACTION** is chosen and fed to our **ENVIRONMENT**, the **ENVIRONMENT** measures how good the action was taken and produces a **REWARD**, which is usually a numeric value. -->
# - When the agent takes an ACTION, the ENVIRONMENT assesses the effectiveness of the action and generates a REWARD, which is usually a numeric value.
#
# Please read the 'Basic usage' https://gymnasium.farama.org/content/basic_usage/ for better understanding the framework.  And do not forget import gymnasium before running other codes.

# %% [markdown]
#  ## 2. Tasks
#
# Next, you will tackle a practical Markov Decision Process (MDP) problem, the 'robot in a maze,' based on the gym framework. Your task involves implementing an RL agent and training it to discover the shortest route to achieve the maze goal. In this MDP, the environment is represented as a grid world (a maze), with the agent being a robot. At each time step, the robot begins at a random location and can move within the grid world. The overarching objective is to find the way out, reaching the final location. Consequently, you will need to identify a fixed goal position within the maze.

# %% [markdown]
# ### 2.1 Model the practical task into a MDP
#
# To solve a RL problem, we start with formalizing the problem into a MDP model. Please describe this MDP model in your report.
#
# Notice: No empricial data provided in this assignment, so the point of 'data description and exploration' will be given to this step.
#
# While exploring your MDP model, you shall think about questions such as:
# - What is the environment? How does it look like?
# - What simulated data can your RL agent observe from the environment? How does it look like?
# - Which data is considered as the state? Which data is considered as the reward?

# %% [markdown]
# #### Set up the environment
#
# There is no need to implement your own environment; you should use the environment provided in the file **environment.py**. However, please ensure to take a look at it so that you understand the inner workings of this environment.
#
# The core gym interface is **Env**, which serves as the unified environment interface. The following are the Env methods you should be familiar with:
#
# - reset(self): Reset the environment's state and return the observation.
# - step(self, action): Advance the environment by one timestep and return the observation, reward, done, and info.
# - render(self, mode='rgb_array'): Render one frame of the environment. The default mode will produce something human-friendly, such as pop up a window. However, in this assignment, there is no need to create a pop-up window.
#
# Please note that you need to install the [mazelab](https://github.com/yupei-du/mazelab.git) package, from **Yupei Du's** repository, to run the environment (a file with required packages is also provided). If you run the cell below for the first time, make sure to restart the IPython notebook at least once.

# %%
#!git clone https://github.com/yupei-du/mazelab.git
#!pip install mazelab
#!pip install pandas
#!pip install seaborn

# %% [markdown]
# You can now check whether the required packages (e.g. mazela, pandas, tqdm, seaborn) are installed. Please install the ones are missing.
#
# ATTENTION: To run the given code, please use the python version 3.7-3.9, and the numpy version < 1.23

# %%
#!pip list

# %% [markdown]
# We also provide a few helper functions to make it easier to debug your agents.
#  - `animate_run` will enable you to see the agent's behavior. It takes a list of images which can be produced by the `env.render` function of the environment
#  - `visualize_agent_brain` will provide you with a way to visualize the agents learned q_table. Use it after you have implemented and trained your agents. The first plot will show the highest q-value per state (position on the map) and the second will tell you which action the agent would choose at that state/position. It takes the environment and the agent as input.
#
# Below you will find a basic example of how the animation function works. Please notice that: whenever you **reset()** the environment, the agent will start at a random position (a different state).

# %%
# libraries
from IPython import get_ipython
import random
from mazelab.generators import random_maze, morris_water_maze
import matplotlib.pyplot as plt
from IPython import display
from mazelab.solvers import dijkstra_solver
import seaborn as sns
from tqdm.notebook import tqdm
from others.environment import TaskEnv
from typing import Tuple, List
import itertools as it
import numpy as np
import pandas as pd
import time

# %%
# The helper functions

def animate_run(data:List[np.ndarray]):
    init_img = data[0]
    remaining_img = data[1:]
    img_container = plt.imshow(init_img)  # only call this once
    for img in remaining_img:
        img_container.set_data(img)  # just update the data
        display.display(plt.gcf())
        display.clear_output(wait=True)
        time.sleep(0.2)


def visualize_agent_brain(agent, env: TaskEnv):
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10, 4))
    ax1.set_title("Highest state value at position (x,y)")
    state_value_map = agent.q_table.max(axis=2)
    sns.heatmap(state_value_map, ax=ax1)

    ax2.set_title("Chosen action at position (x,y)")
    n = env.action_space.n + 1
    path = env.maze.objects.free.positions
    decisions_map = np.array([[x_, y_, agent.select_action([x_, y_]) + 1] for x_, y_ in path])
    state_action_map = np.zeros_like(agent.q_table.max(axis=2))
    state_action_map[decisions_map[:, 0], decisions_map[:, 1]] = decisions_map[:, 2]
    cmap = sns.color_palette("viridis", n)
    sns.heatmap(state_action_map, cmap=cmap, ax=ax2)
    colorbar = ax2.collections[0].colorbar
    r = (colorbar.vmax) - colorbar.vmin
    colorbar.set_ticks([colorbar.vmin + r / n * (0.5 + i) for i in range(n)])
    colorbar.set_ticklabels(['N/A', 'north', 'south', 'west', 'east'])
    fig.tight_layout()
    return plt.show()


env = TaskEnv()
env.reset()
impassable_array = env.unwrapped.maze.to_impassable()
motions = env.unwrapped.motions
start = env.unwrapped.maze.objects.agent.positions[0]
goal = env.unwrapped.maze.objects.goal.positions[0]
actions = dijkstra_solver(impassable_array, motions, start, goal)
print(actions)

imgs = []
rewards = 0.0
for action in actions:
    _, reward, _, _ = env.step(action)
    rewards += reward
    imgs.append(env.render("rgb_array"))
print(rewards)

animate_run(imgs)
plt.show()

# %% [markdown]
# ### 2.2  Implement the agents
#
# In this part, you are expected to implement two RL agents.
#
# - Agent 1 uses the Q-learning algorithm to learn the optimal solution
# - Agent 2 uses the SARSA algorithm to learn the optimal solution. To decide the action to take at each time step,  this agent uses the epsilon greedy action selection.
#
# Here, we have also provided an example agent: the Random Agent.  It follows a random policy to move at each step (randomly selecting an action). You can use this example agent as a baseline to evaluate your agents.

# %%
# Random agent
class RandomAgent():
    def __init__(self, env: TaskEnv,
                 epsilon: float = 1.0,
                 alpha: float = 0.0,
                 gamma: float = 0.0):
        self.epsilon = 1  # A random agent "explores" always, so epsilon will be 1
        self.alpha = 0  # A random agent never learns, so there's no need for a learning rate
        self.gamma = 0  # A random agent does not update it's q-table. Hence, it's zero.
        self.q_table = np.zeros(env.observation_space.shape + (env.action_space.n, ), dtype=float)
        self.actions = env.action_space

    def select_action(self, state: Tuple[int, int], use_greedy_strategy: bool = False):
        if not use_greedy_strategy:
            if random.random() < self.epsilon:
                next_action = self.actions.sample()
                return next_action

        x, y = state
        max_val = np.max(self.q_table[x, y, :])
        find_max_val = np.where(self.q_table[x, y, :] == max_val)
        next_action = np.random.choice(find_max_val[0])
        return next_action
    
    def learn(self, state, action, next_state, next_action, reward, done):
        pass

# %%
# Q-Learning agent
class QL_Agent():
    def __init__(self, 
                 env: TaskEnv,
                 epsilon: float = 0.01,
                 alpha: float = 0.8,
                 gamma: float = 0.99): # defaults for 2000 episodes
        self.epsilon = epsilon
        self.alpha = alpha
        self.gamma = gamma
        self.q_table = np.zeros(env.observation_space.shape + (env.action_space.n, ), dtype=float)
        self.actions = env.action_space

    def select_action(self, state: Tuple[int, int], use_greedy_strategy: bool = False):
        if not use_greedy_strategy:
            if random.random() < self.epsilon:
                next_action = self.actions.sample()
                return next_action

        x, y = state
        max_val = np.max(self.q_table[x, y, :])
        find_max_val = np.where(self.q_table[x, y, :] == max_val)
        next_action = np.random.choice(find_max_val[0]) # Epsilon-greedy policy
        return next_action

    def learn(self, state, action, next_state, next_action, reward, done):
        x, y = state
        next_x, next_y = next_state
        max_val = np.max(self.q_table[next_x, next_y, :])
        self.q_table[x, y, action] += self.alpha * (reward + self.gamma * max_val - self.q_table[x, y, action])

# %%
# SARSA agent
class SARSA_Agent():
    def __init__(self, 
                 env: TaskEnv,
                 epsilon: float = 0.1,
                 alpha: float = 0.8,
                 gamma: float = 0.9):
        self.epsilon = epsilon
        self.alpha = alpha
        self.gamma = gamma
        self.q_table = np.zeros(env.observation_space.shape + (env.action_space.n, ), dtype=float)
        self.actions = env.action_space

    def select_action(self, state: Tuple[int, int], use_greedy_strategy: bool = False):
        if not use_greedy_strategy:
            if random.random() < self.epsilon:
                next_action = self.actions.sample()
                return next_action

        max_val = np.max(self.q_table[state, :])
        find_max_val = np.where(self.q_table[state, :] == max_val)
        next_action = np.random.choice(find_max_val[0]) # Epsilon-greedy policy
        return next_action

    def learn(self, state, action, next_state, next_action, reward, done):
        x, y = state
        next_x, next_y = next_state
        next_val = self.q_table[next_x, next_y, next_action]
        self.q_table[x, y, action] += self.alpha * (reward + self.gamma * next_val - self.q_table[x, y, action])

# %% [markdown]
# ### 2.3 Run the simulation
#
# Now, you write code for running a simulation. In each run, you shall setup the epsilon parameter.

# %%
# run the simulation
def animate_run(data:List[np.ndarray]):
    init_img = data[0]
    remaining_img = data[1:]
    img_container = plt.imshow(init_img)  # only call this once
    for img in remaining_img:
        img_container.set_data(img)  # just update the data
        display.display(plt.gcf())
        display.clear_output(wait=True)

env = TaskEnv()
img = []

# Set up hyperparameters
epsilon = 0.01
alpha = 0.8
gamma = 0.99
epsilon_decay = False
size = 600
agent = QL_Agent(env, epsilon, alpha, gamma)

total_reward = {}
for episode in tqdm(range(size)):
    state = env.reset()
    done = False
    episode_reward = 0

    while not done:
        action = agent.select_action(state)
        next_state, reward, terminated, truncated = env.step(action)
        next_action = agent.select_action(next_state)
        done = terminated or truncated
        episode_reward += reward

        agent.learn(state, action, next_state, next_action, reward, done)
        print(f"Episode: {episode}, Action: {action}, Epsilon: {epsilon}, Reward: {episode_reward}")
        state = next_state
        if isinstance(agent, SARSA_Agent):
            action = next_action    # SARSA's next action is predetermined
        if episode > 0.95 * size:    # only render the last 5% of episodes
            img.append(env.render("rgb_array"))

    # reward tracking
    if episode % 10 == 0:   # avoid too many data points in plot
        total_reward[episode] = episode_reward

    if epsilon > 0.012 and epsilon_decay == True:
        if episode % 10 == 0:
            epsilon -= 0.002

avg_reward = sum(total_reward) / len(total_reward)
print(f"Average episode reward: {avg_reward}")
# Out:
#   0%|          | 0/600 [00:00<?, ?it/s]
# Episode: 0, Action: 3, Epsilon: 0.01, Reward: -1
# Episode: 0, Action: 1, Epsilon: 0.01, Reward: -1.01
# Episode: 0, Action: 3, Epsilon: 0.01, Reward: -1.03
# Episode: 0, Action: 0, Epsilon: 0.01, Reward: -2.0300000000000002
# Episode: 0, Action: 2, Epsilon: 0.01, Reward: -2.0700000000000003
# Episode: 0, Action: 1, Epsilon: 0.01, Reward: -3.0700000000000003
# Episode: 0, Action: 2, Epsilon: 0.01, Reward: -4.07
# Episode: 0, Action: 0, Epsilon: 0.01, Reward: -4.140000000000001
# Episode: 0, Action: 0, Epsilon: 0.01, Reward: -4.220000000000001
# Episode: 0, Action: 2, Epsilon: 0.01, Reward: -5.220000000000001
# Episode: 0, Action: 3, Epsilon: 0.01, Reward: -6.220000000000001
# Episode: 0, Action: 1, Epsilon: 0.01, Reward: -6.330000000000001
# Episode: 0, Action: 2, Epsilon: 0.01, Reward: -7.330000000000001
# Episode: 0, Action: 1, Epsilon: 0.01, Reward: -7.460000000000001
# Episode: 0, Action: 3, Epsilon: 0.01, Reward: -7.6000000000000005
# Episode: 0, Action: 3, Epsilon: 0.01, Reward: -7.750000000000001
# Episode: 0, Action: 3, Epsilon: 0.01, Reward: -7.910000000000001
# Episode: 0, Action: 2, Epsilon: 0.01, Reward: -8.080000000000002
# Episode: 0, Action: 2, Epsilon: 0.01, Reward: -8.260000000000002
# Episode: 0, Action: 1, Epsilon: 0.01, Reward: -9.260000000000002
# Episode: 0, Action: 2, Epsilon: 0.01, Reward: -9.46
# Episode: 0, Action: 0, Epsilon: 0.01, Reward: -9.670000000000002
# Episode: 0, Action: 0, Epsilon: 0.01, Reward: -9.890000000000002
# Episode: 0, Action: 0, Epsilon: 0.01, Reward: -10.120000000000003
# Episode: 0, Action: 2, Epsilon: 0.01, Reward: -11.120000000000003
# Episode: 0, Action: 1, Epsilon: 0.01, Reward: -11.370000000000003
# Episode: 0, Action: 1, Epsilon: 0.01, Reward: -11.630000000000003
# Episode: 0, Action: 1, Epsilon: 0.01, Reward: -11.900000000000002
# Episode: 0, Action: 3, Epsilon: 0.01, Reward: -12.180000000000001
# Episode: 0, Action: 3, Epsilon: 0.01, Reward: -12.47
# Episode: 0, Action: 1, Epsilon: 0.01, Reward: -13.47
# Episode: 0, Action: 0, Epsilon: 0.01, Reward: -13.780000000000001
# Episode: 0, Action: 3, Epsilon: 0.01, Reward: -14.780000000000001
# Episode: 0, Action: 1, Epsilon: 0.01, Reward: -15.110000000000001
# Episode: 0, Action: 3, Epsilon: 0.01, Reward: -15.450000000000001
# Episode: 0, Action: 3, Epsilon: 0.01, Reward: -15.8
# Episode: 0, Action: 0, Epsilon: 0.01, Reward: -16.8
# Episode: 0, Action: 3, Epsilon: 0.01, Reward: -17.17
# Episode: 0, Action: 1, Epsilon: 0.01, Reward: -18.17
# Episode: 0, Action: 0, Epsilon: 0.01, Reward: -19.17
# Episode: 0, Action: 3, Epsilon: 0.01, Reward: -18.17
# Episode: 1, Action: 0, Epsilon: 0.01, Reward: -1
# Episode: 1, Action: 2, Epsilon: 0.01, Reward: -1.01
# Episode: 1, Action: 3, Epsilon: 0.01, Reward: -1.03
# Episode: 1, Action: 3, Epsilon: 0.01, Reward: -1.06
# Episode: 1, Action: 1, Epsilon: 0.01, Reward: -2.06
# Episode: 1, Action: 3, Epsilon: 0.01, Reward: -2.11
# Episode: 1, Action: 2, Epsilon: 0.01, Reward: -2.17
# Episode: 1, Action: 2, Epsilon: 0.01, Reward: -2.2399999999999998
# Episode: 1, Action: 1, Epsilon: 0.01, Reward: -3.2399999999999998
# Episode: 1, Action: 2, Epsilon: 0.01, Reward: -3.3299999999999996
# Episode: 1, Action: 0, Epsilon: 0.01, Reward: -4.33
# Episode: 1, Action: 2, Epsilon: 0.01, Reward: -4.44
# Episode: 1, Action: 0, Epsilon: 0.01, Reward: -5.44
# Episode: 1, Action: 1, Epsilon: 0.01, Reward: -6.44
# Episode: 1, Action: 2, Epsilon: 0.01, Reward: -6.58
# Episode: 1, Action: 1, Epsilon: 0.01, Reward: -7.58
# Episode: 1, Action: 3, Epsilon: 0.01, Reward: -7.74
# Episode: 1, Action: 3, Epsilon: 0.01, Reward: -7.91
# Episode: 1, Action: 1, Epsilon: 0.01, Reward: -8.09
# Episode: 1, Action: 3, Epsilon: 0.01, Reward: -9.09
# Episode: 1, Action: 0, Epsilon: 0.01, Reward: -9.29
# Episode: 1, Action: 3, Epsilon: 0.01, Reward: -9.5
# Episode: 1, Action: 3, Epsilon: 0.01, Reward: -9.72
# Episode: 1, Action: 0, Epsilon: 0.01, Reward: -10.72
# Episode: 1, Action: 3, Epsilon: 0.01, Reward: -10.96
# Episode: 1, Action: 0, Epsilon: 0.01, Reward: -11.96
# Episode: 1, Action: 3, Epsilon: 0.01, Reward: -12.22
# Episode: 1, Action: 2, Epsilon: 0.01, Reward: -12.49
# Episode: 1, Action: 1, Epsilon: 0.01, Reward: -13.49
# Episode: 1, Action: 2, Epsilon: 0.01, Reward: -13.78
# Episode: 1, Action: 2, Epsilon: 0.01, Reward: -14.08
# Episode: 1, Action: 2, Epsilon: 0.01, Reward: -14.39
# Episode: 1, Action: 2, Epsilon: 0.01, Reward: -14.71
# Episode: 1, Action: 2, Epsilon: 0.01, Reward: -15.040000000000001
# Episode: 1, Action: 0, Epsilon: 0.01, Reward: -16.04
# Episode: 1, Action: 2, Epsilon: 0.01, Reward: -16.39
# Episode: 1, Action: 1, Epsilon: 0.01, Reward: -17.39
# Episode: 1, Action: 3, Epsilon: 0.01, Reward: -17.76
# Episode: 1, Action: 3, Epsilon: 0.01, Reward: -18.14
# Episode: 1, Action: 3, Epsilon: 0.01, Reward: -18.53
# Episode: 1, Action: 1, Epsilon: 0.01, Reward: -18.93
# Episode: 1, Action: 1, Epsilon: 0.01, Reward: -19.34
# Episode: 1, Action: 1, Epsilon: 0.01, Reward: -19.76
# Episode: 1, Action: 1, Epsilon: 0.01, Reward: -20.19
# Episode: 1, Action: 1, Epsilon: 0.01, Reward: -21.19
# Episode: 1, Action: 2, Epsilon: 0.01, Reward: -22.19
# Episode: 1, Action: 3, Epsilon: 0.01, Reward: -22.650000000000002
# Episode: 1, Action: 0, Epsilon: 0.01, Reward: -23.650000000000002
# Episode: 1, Action: 3, Epsilon: 0.01, Reward: -24.130000000000003
# Episode: 1, Action: 0, Epsilon: 0.01, Reward: -25.130000000000003
# Episode: 1, Action: 2, Epsilon: 0.01, Reward: -25.630000000000003
# Episode: 1, Action: 2, Epsilon: 0.01, Reward: -26.140000000000004
# Episode: 1, Action: 0, Epsilon: 0.01, Reward: -26.660000000000004
# Episode: 1, Action: 0, Epsilon: 0.01, Reward: -27.190000000000005
# Episode: 1, Action: 2, Epsilon: 0.01, Reward: -27.730000000000004
# Episode: 1, Action: 2, Epsilon: 0.01, Reward: -28.280000000000005
# Episode: 1, Action: 3, Epsilon: 0.01, Reward: -28.840000000000003
# Episode: 1, Action: 1, Epsilon: 0.01, Reward: -29.840000000000003
# Episode: 1, Action: 3, Epsilon: 0.01, Reward: -30.42
# Episode: 1, Action: 3, Epsilon: 0.01, Reward: -31.42
# Episode: 1, Action: 0, Epsilon: 0.01, Reward: -32.02
# Episode: 1, Action: 2, Epsilon: 0.01, Reward: -33.02
# Episode: 1, Action: 0, Epsilon: 0.01, Reward: -33.64
# Episode: 1, Action: 3, Epsilon: 0.01, Reward: -34.27
# Episode: 1, Action: 3, Epsilon: 0.01, Reward: -34.910000000000004
# Episode: 1, Action: 3, Epsilon: 0.01, Reward: -35.56
# Episode: 1, Action: 3, Epsilon: 0.01, Reward: -36.22
# Episode: 1, Action: 0, Epsilon: 0.01, Reward: -37.22
# Episode: 1, Action: 1, Epsilon: 0.01, Reward: -38.22
# Episode: 1, Action: 3, Epsilon: 0.01, Reward: -38.91
# Episode: 1, Action: 2, Epsilon: 0.01, Reward: -39.61
# Episode: 1, Action: 2, Epsilon: 0.01, Reward: -40.32
# Episode: 1, Action: 2, Epsilon: 0.01, Reward: -41.04
# Episode: 1, Action: 2, Epsilon: 0.01, Reward: -41.769999999999996
# Episode: 1, Action: 2, Epsilon: 0.01, Reward: -42.51
# Episode: 1, Action: 1, Epsilon: 0.01, Reward: -43.26
# Episode: 1, Action: 1, Epsilon: 0.01, Reward: -44.019999999999996
# Episode: 1, Action: 1, Epsilon: 0.01, Reward: -44.79
# Episode: 1, Action: 3, Epsilon: 0.01, Reward: -45.79
# Episode: 1, Action: 2, Epsilon: 0.01, Reward: -46.79
# Episode: 1, Action: 1, Epsilon: 0.01, Reward: -47.589999999999996
# Episode: 1, Action: 3, Epsilon: 0.01, Reward: -48.4
# Episode: 1, Action: 1, Epsilon: 0.01, Reward: -49.4
# Episode: 1, Action: 3, Epsilon: 0.01, Reward: -50.23
# Episode: 1, Action: 1, Epsilon: 0.01, Reward: -51.07
# Episode: 1, Action: 2, Epsilon: 0.01, Reward: -52.07
# Episode: 1, Action: 0, Epsilon: 0.01, Reward: -52.93
# Episode: 1, Action: 3, Epsilon: 0.01, Reward: -53.93
# Episode: 1, Action: 2, Epsilon: 0.01, Reward: -54.81
# Episode: 1, Action: 2, Epsilon: 0.01, Reward: -55.7
# Episode: 1, Action: 0, Epsilon: 0.01, Reward: -56.6
# Episode: 1, Action: 0, Epsilon: 0.01, Reward: -57.51
# Episode: 1, Action: 2, Epsilon: 0.01, Reward: -58.43
# Episode: 1, Action: 0, Epsilon: 0.01, Reward: -59.43
# Episode: 1, Action: 2, Epsilon: 0.01, Reward: -60.37
# Episode: 1, Action: 0, Epsilon: 0.01, Reward: -61.37
# Episode: 1, Action: 2, Epsilon: 0.01, Reward: -62.37
# Episode: 1, Action: 1, Epsilon: 0.01, Reward: -63.37
# Episode: 1, Action: 3, Epsilon: 0.01, Reward: -64.35
# Episode: 1, Action: 3, Epsilon: 0.01, Reward: -65.33999999999999
# Episode: 1, Action: 0, Epsilon: 0.01, Reward: -66.33999999999999
# Episode: 2, Action: 0, Epsilon: 0.01, Reward: -1
# Episode: 2, Action: 1, Epsilon: 0.01, Reward: -2
# Episode: 2, Action: 2, Epsilon: 0.01, Reward: -2.02
# Episode: 2, Action: 0, Epsilon: 0.01, Reward: -3.02
# Episode: 2, Action: 2, Epsilon: 0.01, Reward: -3.06
# Episode: 2, Action: 2, Epsilon: 0.01, Reward: -3.11
# Episode: 2, Action: 0, Epsilon: 0.01, Reward: -3.17
# Episode: 2, Action: 1, Epsilon: 0.01, Reward: -3.2399999999999998
# Episode: 2, Action: 1, Epsilon: 0.01, Reward: -3.32
# Episode: 2, Action: 2, Epsilon: 0.01, Reward: -4.32
# Episode: 2, Action: 1, Epsilon: 0.01, Reward: -4.42
# Episode: 2, Action: 2, Epsilon: 0.01, Reward: -5.42
# Episode: 2, Action: 1, Epsilon: 0.01, Reward: -5.54
# Episode: 2, Action: 3, Epsilon: 0.01, Reward: -6.54
# Episode: 2, Action: 1, Epsilon: 0.01, Reward: -6.68
# Episode: 2, Action: 2, Epsilon: 0.01, Reward: -7.68
# Episode: 2, Action: 1, Epsilon: 0.01, Reward: -7.84
# Episode: 2, Action: 0, Epsilon: 0.01, Reward: -8.01
# Episode: 2, Action: 3, Epsilon: 0.01, Reward: -9.01
# Episode: 2, Action: 0, Epsilon: 0.01, Reward: -9.2
# Episode: 2, Action: 0, Epsilon: 0.01, Reward: -9.399999999999999
# Episode: 2, Action: 3, Epsilon: 0.01, Reward: -10.399999999999999
# Episode: 2, Action: 0, Epsilon: 0.01, Reward: -10.62
# Episode: 2, Action: 0, Epsilon: 0.01, Reward: -10.85
# Episode: 2, Action: 2, Epsilon: 0.01, Reward: -11.85
# Episode: 2, Action: 3, Epsilon: 0.01, Reward: -12.1
# Episode: 2, Action: 3, Epsilon: 0.01, Reward: -12.36
# Episode: 2, Action: 1, Epsilon: 0.01, Reward: -13.36
# Episode: 2, Action: 3, Epsilon: 0.01, Reward: -13.639999999999999
# Episode: 2, Action: 1, Epsilon: 0.01, Reward: -14.639999999999999
# Episode: 2, Action: 3, Epsilon: 0.01, Reward: -14.94
# Episode: 2, Action: 0, Epsilon: 0.01, Reward: -15.94
# Episode: 2, Action: 1, Epsilon: 0.01, Reward: -16.259999999999998
# Episode: 2, Action: 0, Epsilon: 0.01, Reward: -16.589999999999996
# Episode: 2, Action: 3, Epsilon: 0.01, Reward: -17.589999999999996
# Episode: 2, Action: 2, Epsilon: 0.01, Reward: -17.939999999999998
# Episode: 2, Action: 2, Epsilon: 0.01, Reward: -18.299999999999997
# Episode: 2, Action: 2, Epsilon: 0.01, Reward: -18.669999999999998
# Episode: 2, Action: 0, Epsilon: 0.01, Reward: -19.669999999999998
# Episode: 2, Action: 1, Epsilon: 0.01, Reward: -20.669999999999998
# Episode: 2, Action: 2, Epsilon: 0.01, Reward: -21.069999999999997
# Episode: 2, Action: 0, Epsilon: 0.01, Reward: -21.479999999999997
# Episode: 2, Action: 3, Epsilon: 0.01, Reward: -22.479999999999997
# Episode: 2, Action: 0, Epsilon: 0.01, Reward: -22.909999999999997
# Episode: 2, Action: 1, Epsilon: 0.01, Reward: -23.349999999999998
# Episode: 2, Action: 2, Epsilon: 0.01, Reward: -24.349999999999998
# Episode: 2, Action: 1, Epsilon: 0.01, Reward: -24.81
# Episode: 2, Action: 1, Epsilon: 0.01, Reward: -25.279999999999998
# Episode: 2, Action: 3, Epsilon: 0.01, Reward: -26.279999999999998
# Episode: 2, Action: 1, Epsilon: 0.01, Reward: -26.769999999999996
# Episode: 2, Action: 1, Epsilon: 0.01, Reward: -27.269999999999996
# Episode: 2, Action: 2, Epsilon: 0.01, Reward: -28.269999999999996
# Episode: 2, Action: 1, Epsilon: 0.01, Reward: -28.789999999999996
# Episode: 2, Action: 1, Epsilon: 0.01, Reward: -29.319999999999997
# Episode: 2, Action: 3, Epsilon: 0.01, Reward: -30.319999999999997
# Episode: 2, Action: 2, Epsilon: 0.01, Reward: -31.319999999999997
# Episode: 2, Action: 1, Epsilon: 0.01, Reward: -31.879999999999995
# Episode: 2, Action: 3, Epsilon: 0.01, Reward: -32.449999999999996
# Episode: 2, Action: 2, Epsilon: 0.01, Reward: -33.029999999999994
# Episode: 2, Action: 1, Epsilon: 0.01, Reward: -34.029999999999994
# Episode: 2, Action: 0, Epsilon: 0.01, Reward: -34.629999999999995
# Episode: 2, Action: 0, Epsilon: 0.01, Reward: -35.239999999999995
# Episode: 2, Action: 0, Epsilon: 0.01, Reward: -35.85999999999999
# Episode: 2, Action: 0, Epsilon: 0.01, Reward: -36.489999999999995
# Episode: 2, Action: 0, Epsilon: 0.01, Reward: -37.129999999999995
# Episode: 2, Action: 0, Epsilon: 0.01, Reward: -37.779999999999994
# Episode: 2, Action: 3, Epsilon: 0.01, Reward: -38.43999999999999
# Episode: 2, Action: 3, Epsilon: 0.01, Reward: -39.10999999999999
# Episode: 2, Action: 3, Epsilon: 0.01, Reward: -39.78999999999999
# Episode: 2, Action: 3, Epsilon: 0.01, Reward: -40.47999999999999
# Episode: 2, Action: 1, Epsilon: 0.01, Reward: -41.17999999999999
# Episode: 2, Action: 3, Epsilon: 0.01, Reward: -42.17999999999999
# Episode: 2, Action: 0, Epsilon: 0.01, Reward: -42.89999999999999
# Episode: 2, Action: 2, Epsilon: 0.01, Reward: -43.62999999999999
# Episode: 2, Action: 2, Epsilon: 0.01, Reward: -44.36999999999999
# Episode: 2, Action: 2, Epsilon: 0.01, Reward: -45.11999999999999
# Episode: 2, Action: 2, Epsilon: 0.01, Reward: -45.87999999999999
# Episode: 2, Action: 0, Epsilon: 0.01, Reward: -46.64999999999999
# Episode: 2, Action: 0, Epsilon: 0.01, Reward: -47.42999999999999
# Episode: 2, Action: 2, Epsilon: 0.01, Reward: -48.42999999999999
# Episode: 2, Action: 3, Epsilon: 0.01, Reward: -49.22999999999999
# Episode: 2, Action: 2, Epsilon: 0.01, Reward: -50.03999999999999
# Episode: 2, Action: 0, Epsilon: 0.01, Reward: -50.85999999999999
# Episode: 2, Action: 3, Epsilon: 0.01, Reward: -51.85999999999999
# Episode: 2, Action: 0, Epsilon: 0.01, Reward: -52.699999999999996
# Episode: 2, Action: 1, Epsilon: 0.01, Reward: -53.55
# Episode: 2, Action: 2, Epsilon: 0.01, Reward: -54.55
# Episode: 2, Action: 1, Epsilon: 0.01, Reward: -55.419999999999995
# Episode: 2, Action: 1, Epsilon: 0.01, Reward: -56.3
# Episode: 2, Action: 1, Epsilon: 0.01, Reward: -57.19
# Episode: 2, Action: 1, Epsilon: 0.01, Reward: -58.089999999999996
# Episode: 2, Action: 1, Epsilon: 0.01, Reward: -58.99999999999999
# Episode: 2, Action: 1, Epsilon: 0.01, Reward: -59.919999999999995
# Episode: 2, Action: 1, Epsilon: 0.01, Reward: -60.849999999999994
# Episode: 2, Action: 1, Epsilon: 0.01, Reward: -61.78999999999999
# Episode: 2, Action: 1, Epsilon: 0.01, Reward: -62.739999999999995
# Episode: 2, Action: 2, Epsilon: 0.01, Reward: -63.739999999999995
# Episode: 2, Action: 3, Epsilon: 0.01, Reward: -64.71
# Episode: 2, Action: 0, Epsilon: 0.01, Reward: -65.71
# Episode: 2, Action: 1, Epsilon: 0.01, Reward: -66.71
# Episode: 2, Action: 3, Epsilon: 0.01, Reward: -67.71
# Episode: 3, Action: 0, Epsilon: 0.01, Reward: 0.0
# Episode: 3, Action: 1, Epsilon: 0.01, Reward: -0.01
# Episode: 3, Action: 0, Epsilon: 0.01, Reward: -0.03
# Episode: 3, Action: 0, Epsilon: 0.01, Reward: -0.06
# Episode: 3, Action: 0, Epsilon: 0.01, Reward: -0.1
# Episode: 3, Action: 3, Epsilon: 0.01, Reward: -0.15000000000000002
# Episode: 3, Action: 3, Epsilon: 0.01, Reward: -0.21000000000000002
# Episode: 3, Action: 3, Epsilon: 0.01, Reward: -0.28
# Episode: 3, Action: 0, Epsilon: 0.01, Reward: -1.28
# Episode: 3, Action: 3, Epsilon: 0.01, Reward: -1.37
# Episode: 3, Action: 1, Epsilon: 0.01, Reward: -1.4700000000000002
# Episode: 3, Action: 1, Epsilon: 0.01, Reward: -1.5800000000000003
# Episode: 3, Action: 0, Epsilon: 0.01, Reward: -1.7000000000000002
# Episode: 3, Action: 1, Epsilon: 0.01, Reward: -1.83
# Episode: 3, Action: 1, Epsilon: 0.01, Reward: -1.9700000000000002
# Episode: 3, Action: 0, Epsilon: 0.01, Reward: -2.12
# Episode: 3, Action: 1, Epsilon: 0.01, Reward: -2.2800000000000002
# Episode: 3, Action: 1, Epsilon: 0.01, Reward: -2.45
# Episode: 3, Action: 0, Epsilon: 0.01, Reward: -2.6300000000000003
# Episode: 3, Action: 1, Epsilon: 0.01, Reward: -2.8200000000000003
# Episode: 3, Action: 3, Epsilon: 0.01, Reward: -3.0200000000000005
# Episode: 3, Action: 2, Epsilon: 0.01, Reward: -3.2300000000000004
# Episode: 3, Action: 3, Epsilon: 0.01, Reward: -3.4500000000000006
# Episode: 3, Action: 3, Epsilon: 0.01, Reward: -3.6800000000000006
# Episode: 3, Action: 2, Epsilon: 0.01, Reward: -3.920000000000001
# Episode: 3, Action: 3, Epsilon: 0.01, Reward: -4.170000000000001
# Episode: 3, Action: 0, Epsilon: 0.01, Reward: -4.430000000000001
# Episode: 3, Action: 2, Epsilon: 0.01, Reward: -5.430000000000001
# Episode: 3, Action: 0, Epsilon: 0.01, Reward: -5.710000000000001
# Episode: 3, Action: 3, Epsilon: 0.01, Reward: -6.710000000000001
# Episode: 3, Action: 1, Epsilon: 0.01, Reward: -7.010000000000001
# Episode: 3, Action: 0, Epsilon: 0.01, Reward: -7.32
# Episode: 3, Action: 2, Epsilon: 0.01, Reward: -8.32
# Episode: 3, Action: 0, Epsilon: 0.01, Reward: -8.65
# Episode: 3, Action: 1, Epsilon: 0.01, Reward: -8.99
# Episode: 3, Action: 0, Epsilon: 0.01, Reward: -9.34
# Episode: 3, Action: 0, Epsilon: 0.01, Reward: -9.7
# Episode: 3, Action: 3, Epsilon: 0.01, Reward: -10.7
# Episode: 3, Action: 2, Epsilon: 0.01, Reward: -11.7
# Episode: 3, Action: 0, Epsilon: 0.01, Reward: -12.09
# Episode: 3, Action: 3, Epsilon: 0.01, Reward: -13.09
# Episode: 3, Action: 1, Epsilon: 0.01, Reward: -13.5
# Episode: 3, Action: 1, Epsilon: 0.01, Reward: -13.92
# Episode: 3, Action: 3, Epsilon: 0.01, Reward: -14.92
# Episode: 3, Action: 2, Epsilon: 0.01, Reward: -15.92
# Episode: 3, Action: 2, Epsilon: 0.01, Reward: -16.92
# Episode: 3, Action: 0, Epsilon: 0.01, Reward: -17.380000000000003
# Episode: 3, Action: 0, Epsilon: 0.01, Reward: -17.85
# Episode: 3, Action: 1, Epsilon: 0.01, Reward: -18.330000000000002
# Episode: 3, Action: 1, Epsilon: 0.01, Reward: -18.82
# Episode: 3, Action: 1, Epsilon: 0.01, Reward: -19.32
# Episode: 3, Action: 0, Epsilon: 0.01, Reward: -19.830000000000002
# Episode: 3, Action: 0, Epsilon: 0.01, Reward: -20.35
# Episode: 3, Action: 0, Epsilon: 0.01, Reward: -20.880000000000003
# Episode: 3, Action: 0, Epsilon: 0.01, Reward: -21.42
# Episode: 3, Action: 1, Epsilon: 0.01, Reward: -21.970000000000002
# Episode: 3, Action: 1, Epsilon: 0.01, Reward: -22.53
# Episode: 3, Action: 2, Epsilon: 0.01, Reward: -23.53
# Episode: 3, Action: 3, Epsilon: 0.01, Reward: -24.53
# Episode: 3, Action: 1, Epsilon: 0.01, Reward: -25.12
# Episode: 3, Action: 1, Epsilon: 0.01, Reward: -25.720000000000002
# Episode: 3, Action: 1, Epsilon: 0.01, Reward: -26.330000000000002
# Episode: 3, Action: 0, Epsilon: 0.01, Reward: -26.950000000000003
# Episode: 3, Action: 2, Epsilon: 0.01, Reward: -27.950000000000003
# Episode: 3, Action: 3, Epsilon: 0.01, Reward: -28.950000000000003
# Episode: 3, Action: 1, Epsilon: 0.01, Reward: -29.6
# Episode: 3, Action: 1, Epsilon: 0.01, Reward: -30.26
# Episode: 3, Action: 0, Epsilon: 0.01, Reward: -30.930000000000003
# Episode: 3, Action: 2, Epsilon: 0.01, Reward: -31.930000000000003
# Episode: 3, Action: 3, Epsilon: 0.01, Reward: -32.93000000000001
# Episode: 3, Action: 1, Epsilon: 0.01, Reward: -33.63000000000001
# Episode: 3, Action: 3, Epsilon: 0.01, Reward: -34.34000000000001
# Episode: 3, Action: 1, Epsilon: 0.01, Reward: -35.34000000000001
# Episode: 3, Action: 0, Epsilon: 0.01, Reward: -36.34000000000001
# Episode: 3, Action: 2, Epsilon: 0.01, Reward: -37.08000000000001
# Episode: 3, Action: 2, Epsilon: 0.01, Reward: -37.83000000000001
# Episode: 3, Action: 3, Epsilon: 0.01, Reward: -38.59000000000001
# Episode: 3, Action: 3, Epsilon: 0.01, Reward: -39.360000000000014
# Episode: 3, Action: 3, Epsilon: 0.01, Reward: -40.140000000000015
# Episode: 3, Action: 1, Epsilon: 0.01, Reward: -41.140000000000015
# Episode: 3, Action: 2, Epsilon: 0.01, Reward: -41.94000000000001
# Episode: 3, Action: 3, Epsilon: 0.01, Reward: -42.750000000000014
# Episode: 3, Action: 3, Epsilon: 0.01, Reward: -43.570000000000014
# Episode: 3, Action: 3, Epsilon: 0.01, Reward: -42.570000000000014
# Episode: 4, Action: 0, Epsilon: 0.01, Reward: -1
# Episode: 4, Action: 3, Epsilon: 0.01, Reward: -1.01
# Episode: 4, Action: 0, Epsilon: 0.01, Reward: -2.01
# Episode: 4, Action: 3, Epsilon: 0.01, Reward: -3.01
# Episode: 4, Action: 1, Epsilon: 0.01, Reward: -4.01
# Episode: 4, Action: 2, Epsilon: 0.01, Reward: -4.06
# Episode: 4, Action: 1, Epsilon: 0.01, Reward: -5.06
# Episode: 4, Action: 2, Epsilon: 0.01, Reward: -5.13
# Episode: 4, Action: 1, Epsilon: 0.01, Reward: -6.13
# Episode: 4, Action: 2, Epsilon: 0.01, Reward: -6.22
# Episode: 4, Action: 1, Epsilon: 0.01, Reward: -7.22
# Episode: 4, Action: 0, Epsilon: 0.01, Reward: -8.219999999999999
# Episode: 4, Action: 2, Epsilon: 0.01, Reward: -8.339999999999998
# Episode: 4, Action: 1, Epsilon: 0.01, Reward: -9.339999999999998
# Episode: 4, Action: 3, Epsilon: 0.01, Reward: -9.479999999999999
# Episode: 4, Action: 3, Epsilon: 0.01, Reward: -9.629999999999999
# Episode: 4, Action: 0, Epsilon: 0.01, Reward: -10.629999999999999
# Episode: 4, Action: 3, Epsilon: 0.01, Reward: -10.799999999999999
# Episode: 4, Action: 3, Epsilon: 0.01, Reward: -10.979999999999999
# Episode: 4, Action: 2, Epsilon: 0.01, Reward: -11.169999999999998
# Episode: 4, Action: 2, Epsilon: 0.01, Reward: -11.369999999999997
# Episode: 4, Action: 2, Epsilon: 0.01, Reward: -11.579999999999998
# Episode: 4, Action: 2, Epsilon: 0.01, Reward: -11.799999999999999
# Episode: 4, Action: 0, Epsilon: 0.01, Reward: -12.799999999999999
# Episode: 4, Action: 2, Epsilon: 0.01, Reward: -13.04
# Episode: 4, Action: 3, Epsilon: 0.01, Reward: -13.29
# Episode: 4, Action: 3, Epsilon: 0.01, Reward: -13.549999999999999
# Episode: 4, Action: 3, Epsilon: 0.01, Reward: -13.819999999999999
# Episode: 4, Action: 3, Epsilon: 0.01, Reward: -14.099999999999998
# Episode: 4, Action: 3, Epsilon: 0.01, Reward: -14.389999999999997
# Episode: 4, Action: 2, Epsilon: 0.01, Reward: -14.689999999999998
# Episode: 4, Action: 2, Epsilon: 0.01, Reward: -14.999999999999998
# Episode: 4, Action: 2, Epsilon: 0.01, Reward: -15.319999999999999
# Episode: 4, Action: 2, Epsilon: 0.01, Reward: -15.649999999999999
# Episode: 4, Action: 2, Epsilon: 0.01, Reward: -15.989999999999998
# Episode: 4, Action: 2, Epsilon: 0.01, Reward: -16.34
# Episode: 4, Action: 0, Epsilon: 0.01, Reward: -16.7
# Episode: 4, Action: 3, Epsilon: 0.01, Reward: -17.7
# Episode: 4, Action: 0, Epsilon: 0.01, Reward: -18.08
# Episode: 4, Action: 3, Epsilon: 0.01, Reward: -19.08
# Episode: 4, Action: 2, Epsilon: 0.01, Reward: -20.08
# Episode: 4, Action: 0, Epsilon: 0.01, Reward: -20.49
# Episode: 4, Action: 1, Epsilon: 0.01, Reward: -20.91
# Episode: 4, Action: 1, Epsilon: 0.01, Reward: -21.34
# Episode: 4, Action: 2, Epsilon: 0.01, Reward: -22.34
# Episode: 4, Action: 1, Epsilon: 0.01, Reward: -22.79
# Episode: 4, Action: 1, Epsilon: 0.01, Reward: -23.79
# Episode: 4, Action: 2, Epsilon: 0.01, Reward: -24.259999999999998
# Episode: 4, Action: 2, Epsilon: 0.01, Reward: -24.74
# Episode: 4, Action: 0, Epsilon: 0.01, Reward: -25.229999999999997
# Episode: 4, Action: 0, Epsilon: 0.01, Reward: -25.729999999999997
# Episode: 4, Action: 0, Epsilon: 0.01, Reward: -26.24
# Episode: 4, Action: 0, Epsilon: 0.01, Reward: -26.759999999999998
# Episode: 4, Action: 0, Epsilon: 0.01, Reward: -27.29
# Episode: 4, Action: 0, Epsilon: 0.01, Reward: -27.83
# Episode: 4, Action: 3, Epsilon: 0.01, Reward: -28.38
# Episode: 4, Action: 0, Epsilon: 0.01, Reward: -29.38
# Episode: 4, Action: 1, Epsilon: 0.01, Reward: -30.38
# Episode: 4, Action: 3, Epsilon: 0.01, Reward: -30.959999999999997
# Episode: 4, Action: 0, Epsilon: 0.01, Reward: -31.959999999999997
# Episode: 4, Action: 1, Epsilon: 0.01, Reward: -32.959999999999994
# Episode: 4, Action: 3, Epsilon: 0.01, Reward: -33.56999999999999
# Episode: 4, Action: 3, Epsilon: 0.01, Reward: -34.18999999999999
# Episode: 4, Action: 1, Epsilon: 0.01, Reward: -34.81999999999999
# Episode: 4, Action: 1, Epsilon: 0.01, Reward: -35.459999999999994
# Episode: 4, Action: 0, Epsilon: 0.01, Reward: -36.10999999999999
# Episode: 4, Action: 2, Epsilon: 0.01, Reward: -37.10999999999999
# Episode: 4, Action: 3, Epsilon: 0.01, Reward: -38.10999999999999
# Episode: 4, Action: 0, Epsilon: 0.01, Reward: -38.78999999999999
# Episode: 4, Action: 0, Epsilon: 0.01, Reward: -39.78999999999999
# Episode: 4, Action: 3, Epsilon: 0.01, Reward: -40.78999999999999
# Episode: 4, Action: 2, Epsilon: 0.01, Reward: -41.49999999999999
# Episode: 4, Action: 2, Epsilon: 0.01, Reward: -42.21999999999999
# Episode: 4, Action: 2, Epsilon: 0.01, Reward: -42.94999999999999
# Episode: 4, Action: 2, Epsilon: 0.01, Reward: -43.68999999999999
# Episode: 4, Action: 2, Epsilon: 0.01, Reward: -44.68999999999999
# Episode: 4, Action: 0, Epsilon: 0.01, Reward: -45.44999999999999
# Episode: 4, Action: 0, Epsilon: 0.01, Reward: -46.21999999999999
# Episode: 4, Action: 3, Epsilon: 0.01, Reward: -46.99999999999999
# Episode: 4, Action: 3, Epsilon: 0.01, Reward: -47.78999999999999
# Episode: 4, Action: 1, Epsilon: 0.01, Reward: -48.78999999999999
# Episode: 4, Action: 0, Epsilon: 0.01, Reward: -49.78999999999999
# Episode: 4, Action: 2, Epsilon: 0.01, Reward: -50.60999999999999
# Episode: 4, Action: 1, Epsilon: 0.01, Reward: -51.60999999999999
# Episode: 4, Action: 0, Epsilon: 0.01, Reward: -52.60999999999999
# Episode: 4, Action: 3, Epsilon: 0.01, Reward: -53.459999999999994
# Episode: 4, Action: 3, Epsilon: 0.01, Reward: -54.459999999999994
# Episode: 4, Action: 2, Epsilon: 0.01, Reward: -55.32999999999999
# Episode: 4, Action: 2, Epsilon: 0.01, Reward: -56.209999999999994
# Episode: 4, Action: 0, Epsilon: 0.01, Reward: -57.099999999999994
# Episode: 4, Action: 0, Epsilon: 0.01, Reward: -57.99999999999999
# Episode: 4, Action: 2, Epsilon: 0.01, Reward: -58.99999999999999
# Episode: 4, Action: 0, Epsilon: 0.01, Reward: -59.919999999999995
# Episode: 4, Action: 2, Epsilon: 0.01, Reward: -60.919999999999995
# Episode: 4, Action: 1, Epsilon: 0.01, Reward: -61.85999999999999
# Episode: 4, Action: 3, Epsilon: 0.01, Reward: -62.85999999999999
# Episode: 4, Action: 1, Epsilon: 0.01, Reward: -63.81999999999999
# Episode: 4, Action: 2, Epsilon: 0.01, Reward: -64.82
# Episode: 4, Action: 3, Epsilon: 0.01, Reward: -65.82
# Episode: 4, Action: 0, Epsilon: 0.01, Reward: -66.80999999999999
# Episode: 4, Action: 0, Epsilon: 0.01, Reward: -67.80999999999999
# Episode: 5, Action: 2, Epsilon: 0.01, Reward: 0.0
# Episode: 5, Action: 0, Epsilon: 0.01, Reward: -1.0
# Episode: 5, Action: 1, Epsilon: 0.01, Reward: -2.0
# Episode: 5, Action: 3, Epsilon: 0.01, Reward: -2.03
# Episode: 5, Action: 0, Epsilon: 0.01, Reward: -3.03
# Episode: 5, Action: 3, Epsilon: 0.01, Reward: -3.0799999999999996
# Episode: 5, Action: 3, Epsilon: 0.01, Reward: -3.1399999999999997
# Episode: 5, Action: 2, Epsilon: 0.01, Reward: -3.2099999999999995
# Episode: 5, Action: 0, Epsilon: 0.01, Reward: -4.209999999999999
# Episode: 5, Action: 1, Epsilon: 0.01, Reward: -5.209999999999999
# Episode: 5, Action: 2, Epsilon: 0.01, Reward: -5.309999999999999
# Episode: 5, Action: 1, Epsilon: 0.01, Reward: -6.309999999999999
# Episode: 5, Action: 2, Epsilon: 0.01, Reward: -6.429999999999999
# Episode: 5, Action: 2, Epsilon: 0.01, Reward: -6.559999999999999
# Episode: 5, Action: 2, Epsilon: 0.01, Reward: -7.559999999999999
# Episode: 5, Action: 1, Epsilon: 0.01, Reward: -8.559999999999999
# Episode: 5, Action: 0, Epsilon: 0.01, Reward: -8.719999999999999
# Episode: 5, Action: 3, Epsilon: 0.01, Reward: -9.719999999999999
# Episode: 5, Action: 0, Epsilon: 0.01, Reward: -9.899999999999999
# Episode: 5, Action: 0, Epsilon: 0.01, Reward: -10.089999999999998
# Episode: 5, Action: 3, Epsilon: 0.01, Reward: -11.089999999999998
# Episode: 5, Action: 0, Epsilon: 0.01, Reward: -11.299999999999999
# Episode: 5, Action: 3, Epsilon: 0.01, Reward: -12.299999999999999
# Episode: 5, Action: 0, Epsilon: 0.01, Reward: -12.53
# Episode: 5, Action: 1, Epsilon: 0.01, Reward: -12.77
# Episode: 5, Action: 1, Epsilon: 0.01, Reward: -13.02
# Episode: 5, Action: 2, Epsilon: 0.01, Reward: -14.02
# Episode: 5, Action: 1, Epsilon: 0.01, Reward: -14.29
# Episode: 5, Action: 2, Epsilon: 0.01, Reward: -15.29
# Episode: 5, Action: 1, Epsilon: 0.01, Reward: -15.579999999999998
# Episode: 5, Action: 2, Epsilon: 0.01, Reward: -16.58
# Episode: 5, Action: 1, Epsilon: 0.01, Reward: -16.889999999999997
# Episode: 5, Action: 3, Epsilon: 0.01, Reward: -17.209999999999997
# Episode: 5, Action: 3, Epsilon: 0.01, Reward: -17.539999999999996
# Episode: 5, Action: 3, Epsilon: 0.01, Reward: -17.879999999999995
# Episode: 5, Action: 3, Epsilon: 0.01, Reward: -18.229999999999997
# Episode: 5, Action: 1, Epsilon: 0.01, Reward: -18.589999999999996
# Episode: 5, Action: 1, Epsilon: 0.01, Reward: -18.959999999999997
# Episode: 5, Action: 0, Epsilon: 0.01, Reward: -19.339999999999996
# Episode: 5, Action: 2, Epsilon: 0.01, Reward: -20.339999999999996
# Episode: 5, Action: 0, Epsilon: 0.01, Reward: -20.739999999999995
# Episode: 5, Action: 3, Epsilon: 0.01, Reward: -21.739999999999995
# Episode: 5, Action: 0, Epsilon: 0.01, Reward: -22.159999999999997
# Episode: 5, Action: 0, Epsilon: 0.01, Reward: -22.589999999999996
# Episode: 5, Action: 0, Epsilon: 0.01, Reward: -23.029999999999998
# Episode: 5, Action: 3, Epsilon: 0.01, Reward: -24.029999999999998
# Episode: 5, Action: 1, Epsilon: 0.01, Reward: -24.49
# Episode: 5, Action: 3, Epsilon: 0.01, Reward: -25.49
# Episode: 5, Action: 1, Epsilon: 0.01, Reward: -25.97
# Episode: 5, Action: 1, Epsilon: 0.01, Reward: -26.459999999999997
# Episode: 5, Action: 2, Epsilon: 0.01, Reward: -26.959999999999997
# Episode: 5, Action: 2, Epsilon: 0.01, Reward: -27.47
# Episode: 5, Action: 2, Epsilon: 0.01, Reward: -27.99
# Episode: 5, Action: 2, Epsilon: 0.01, Reward: -28.52
# Episode: 5, Action: 0, Epsilon: 0.01, Reward: -29.06
# Episode: 5, Action: 0, Epsilon: 0.01, Reward: -29.61
# Episode: 5, Action: 3, Epsilon: 0.01, Reward: -30.169999999999998
# Episode: 5, Action: 0, Epsilon: 0.01, Reward: -31.169999999999998
# Episode: 5, Action: 2, Epsilon: 0.01, Reward: -31.749999999999996
# Episode: 5, Action: 0, Epsilon: 0.01, Reward: -32.339999999999996
# Episode: 5, Action: 0, Epsilon: 0.01, Reward: -32.94
# Episode: 5, Action: 2, Epsilon: 0.01, Reward: -33.94
# Episode: 5, Action: 0, Epsilon: 0.01, Reward: -34.559999999999995
# Episode: 5, Action: 2, Epsilon: 0.01, Reward: -35.559999999999995
# Episode: 5, Action: 3, Epsilon: 0.01, Reward: -36.559999999999995
# Episode: 5, Action: 0, Epsilon: 0.01, Reward: -37.209999999999994
# Episode: 5, Action: 1, Epsilon: 0.01, Reward: -37.86999999999999
# Episode: 5, Action: 1, Epsilon: 0.01, Reward: -38.53999999999999
# Episode: 5, Action: 1, Epsilon: 0.01, Reward: -39.21999999999999
# Episode: 5, Action: 1, Epsilon: 0.01, Reward: -39.90999999999999
# Episode: 5, Action: 1, Epsilon: 0.01, Reward: -40.60999999999999
# Episode: 5, Action: 1, Epsilon: 0.01, Reward: -41.31999999999999
# Episode: 5, Action: 3, Epsilon: 0.01, Reward: -42.03999999999999
# Episode: 5, Action: 3, Epsilon: 0.01, Reward: -42.76999999999999
# Episode: 5, Action: 3, Epsilon: 0.01, Reward: -43.50999999999999
# Episode: 5, Action: 3, Epsilon: 0.01, Reward: -44.25999999999999
# Episode: 5, Action: 1, Epsilon: 0.01, Reward: -45.01999999999999
# Episode: 5, Action: 3, Epsilon: 0.01, Reward: -46.01999999999999
# Episode: 5, Action: 1, Epsilon: 0.01, Reward: -46.79999999999999
# Episode: 5, Action: 1, Epsilon: 0.01, Reward: -47.58999999999999
# Episode: 5, Action: 2, Epsilon: 0.01, Reward: -48.58999999999999
# Episode: 5, Action: 1, Epsilon: 0.01, Reward: -49.39999999999999
# Episode: 5, Action: 0, Epsilon: 0.01, Reward: -50.21999999999999
# Episode: 5, Action: 0, Epsilon: 0.01, Reward: -51.04999999999999
# Episode: 5, Action: 3, Epsilon: 0.01, Reward: -52.04999999999999
# Episode: 5, Action: 2, Epsilon: 0.01, Reward: -53.04999999999999
# Episode: 5, Action: 0, Epsilon: 0.01, Reward: -53.90999999999999
# Episode: 5, Action: 0, Epsilon: 0.01, Reward: -54.77999999999999
# Episode: 5, Action: 0, Epsilon: 0.01, Reward: -55.65999999999999
# Episode: 5, Action: 3, Epsilon: 0.01, Reward: -56.65999999999999
# Episode: 5, Action: 2, Epsilon: 0.01, Reward: -57.65999999999999
# Episode: 5, Action: 0, Epsilon: 0.01, Reward: -58.569999999999986
# Episode: 5, Action: 2, Epsilon: 0.01, Reward: -59.569999999999986
# Episode: 5, Action: 0, Epsilon: 0.01, Reward: -60.499999999999986
# Episode: 5, Action: 0, Epsilon: 0.01, Reward: -61.43999999999998
# Episode: 5, Action: 3, Epsilon: 0.01, Reward: -62.43999999999998
# Episode: 5, Action: 1, Epsilon: 0.01, Reward: -63.399999999999984
# Episode: 5, Action: 2, Epsilon: 0.01, Reward: -64.39999999999998
# Episode: 5, Action: 1, Epsilon: 0.01, Reward: -65.37999999999998
# Episode: 5, Action: 1, Epsilon: 0.01, Reward: -66.36999999999998
# Episode: 5, Action: 1, Epsilon: 0.01, Reward: -67.36999999999998
# Episode: 6, Action: 1, Epsilon: 0.01, Reward: 0.0
# Episode: 6, Action: 1, Epsilon: 0.01, Reward: -0.01
# Episode: 6, Action: 3, Epsilon: 0.01, Reward: -1.01
# Episode: 6, Action: 1, Epsilon: 0.01, Reward: -1.04
# Episode: 6, Action: 1, Epsilon: 0.01, Reward: -2.04
# Episode: 6, Action: 2, Epsilon: 0.01, Reward: -2.09
# Episode: 6, Action: 3, Epsilon: 0.01, Reward: -2.15
# Episode: 6, Action: 3, Epsilon: 0.01, Reward: -3.15
# Episode: 6, Action: 2, Epsilon: 0.01, Reward: -3.23
# Episode: 6, Action: 0, Epsilon: 0.01, Reward: -4.23
# Episode: 6, Action: 1, Epsilon: 0.01, Reward: -5.23
# Episode: 6, Action: 2, Epsilon: 0.01, Reward: -5.340000000000001
# Episode: 6, Action: 2, Epsilon: 0.01, Reward: -6.340000000000001
# Episode: 6, Action: 1, Epsilon: 0.01, Reward: -7.340000000000001
# Episode: 6, Action: 0, Epsilon: 0.01, Reward: -7.48
# Episode: 6, Action: 0, Epsilon: 0.01, Reward: -6.48
# Episode: 7, Action: 0, Epsilon: 0.01, Reward: -1
# Episode: 7, Action: 1, Epsilon: 0.01, Reward: -2
# Episode: 7, Action: 2, Epsilon: 0.01, Reward: -2.02
# Episode: 7, Action: 1, Epsilon: 0.01, Reward: -3.02
# Episode: 7, Action: 3, Epsilon: 0.01, Reward: -3.06
# Episode: 7, Action: 2, Epsilon: 0.01, Reward: -3.11
# Episode: 7, Action: 3, Epsilon: 0.01, Reward: -3.17
# Episode: 7, Action: 2, Epsilon: 0.01, Reward: -3.2399999999999998
# Episode: 7, Action: 3, Epsilon: 0.01, Reward: -3.32
# Episode: 7, Action: 2, Epsilon: 0.01, Reward: -3.4099999999999997
# Episode: 7, Action: 3, Epsilon: 0.01, Reward: -3.51
# Episode: 7, Action: 3, Epsilon: 0.01, Reward: -3.6199999999999997
# Episode: 7, Action: 3, Epsilon: 0.01, Reward: -3.7399999999999998
# Episode: 7, Action: 3, Epsilon: 0.01, Reward: -2.7399999999999998
# Episode: 8, Action: 0, Epsilon: 0.01, Reward: -1
# Episode: 8, Action: 2, Epsilon: 0.01, Reward: -1.01
# Episode: 8, Action: 1, Epsilon: 0.01, Reward: -2.01
# Episode: 8, Action: 3, Epsilon: 0.01, Reward: -2.0399999999999996
# Episode: 8, Action: 3, Epsilon: 0.01, Reward: -3.0399999999999996
# Episode: 8, Action: 1, Epsilon: 0.01, Reward: -3.0899999999999994
# Episode: 8, Action: 1, Epsilon: 0.01, Reward: -3.1499999999999995
# Episode: 8, Action: 1, Epsilon: 0.01, Reward: -3.2199999999999993
# Episode: 8, Action: 3, Epsilon: 0.01, Reward: -4.219999999999999
# Episode: 8, Action: 1, Epsilon: 0.01, Reward: -4.309999999999999
# Episode: 8, Action: 2, Epsilon: 0.01, Reward: -4.409999999999998
# Episode: 8, Action: 3, Epsilon: 0.01, Reward: -4.519999999999999
# Episode: 8, Action: 0, Epsilon: 0.01, Reward: -4.639999999999999
# Episode: 8, Action: 2, Epsilon: 0.01, Reward: -5.639999999999999
# Episode: 8, Action: 0, Epsilon: 0.01, Reward: -5.7799999999999985
# Episode: 8, Action: 2, Epsilon: 0.01, Reward: -6.7799999999999985
# Episode: 8, Action: 3, Epsilon: 0.01, Reward: -7.7799999999999985
# Episode: 8, Action: 0, Epsilon: 0.01, Reward: -7.949999999999998
# Episode: 8, Action: 0, Epsilon: 0.01, Reward: -8.129999999999999
# Episode: 8, Action: 2, Epsilon: 0.01, Reward: -8.319999999999999
# Episode: 8, Action: 2, Epsilon: 0.01, Reward: -8.519999999999998
# Episode: 8, Action: 3, Epsilon: 0.01, Reward: -8.729999999999999
# Episode: 8, Action: 0, Epsilon: 0.01, Reward: -9.729999999999999
# Episode: 8, Action: 3, Epsilon: 0.01, Reward: -9.959999999999999
# Episode: 8, Action: 1, Epsilon: 0.01, Reward: -10.2
# Episode: 8, Action: 2, Epsilon: 0.01, Reward: -11.2
# Episode: 8, Action: 3, Epsilon: 0.01, Reward: -12.2
# Episode: 8, Action: 1, Epsilon: 0.01, Reward: -12.469999999999999
# Episode: 8, Action: 1, Epsilon: 0.01, Reward: -12.749999999999998
# Episode: 8, Action: 1, Epsilon: 0.01, Reward: -13.039999999999997
# Episode: 8, Action: 2, Epsilon: 0.01, Reward: -13.339999999999998
# Episode: 8, Action: 1, Epsilon: 0.01, Reward: -14.339999999999998
# Episode: 8, Action: 0, Epsilon: 0.01, Reward: -15.339999999999998
# Episode: 8, Action: 2, Epsilon: 0.01, Reward: -15.669999999999998
# Episode: 8, Action: 1, Epsilon: 0.01, Reward: -16.669999999999998
# Episode: 8, Action: 2, Epsilon: 0.01, Reward: -17.669999999999998
# Episode: 8, Action: 0, Epsilon: 0.01, Reward: -18.669999999999998
# Episode: 8, Action: 3, Epsilon: 0.01, Reward: -19.04
# Episode: 8, Action: 3, Epsilon: 0.01, Reward: -19.419999999999998
# Episode: 8, Action: 0, Epsilon: 0.01, Reward: -19.81
# Episode: 8, Action: 0, Epsilon: 0.01, Reward: -20.209999999999997
# Episode: 8, Action: 0, Epsilon: 0.01, Reward: -20.619999999999997
# Episode: 8, Action: 0, Epsilon: 0.01, Reward: -21.04
# Episode: 8, Action: 2, Epsilon: 0.01, Reward: -21.47
# Episode: 8, Action: 2, Epsilon: 0.01, Reward: -21.91
# Episode: 8, Action: 2, Epsilon: 0.01, Reward: -22.36
# Episode: 8, Action: 1, Epsilon: 0.01, Reward: -23.36
# Episode: 8, Action: 0, Epsilon: 0.01, Reward: -24.36
# Episode: 8, Action: 3, Epsilon: 0.01, Reward: -24.84
# Episode: 8, Action: 1, Epsilon: 0.01, Reward: -25.84
# Episode: 8, Action: 0, Epsilon: 0.01, Reward: -26.84
# Episode: 8, Action: 3, Epsilon: 0.01, Reward: -27.35
# Episode: 8, Action: 3, Epsilon: 0.01, Reward: -27.87
# Episode: 8, Action: 1, Epsilon: 0.01, Reward: -28.400000000000002
# Episode: 8, Action: 1, Epsilon: 0.01, Reward: -28.94
# Episode: 8, Action: 1, Epsilon: 0.01, Reward: -29.490000000000002
# Episode: 8, Action: 1, Epsilon: 0.01, Reward: -30.05
# Episode: 8, Action: 2, Epsilon: 0.01, Reward: -30.62
# Episode: 8, Action: 2, Epsilon: 0.01, Reward: -31.2
# Episode: 8, Action: 3, Epsilon: 0.01, Reward: -31.79
# Episode: 8, Action: 3, Epsilon: 0.01, Reward: -32.39
# Episode: 8, Action: 0, Epsilon: 0.01, Reward: -33.0
# Episode: 8, Action: 0, Epsilon: 0.01, Reward: -33.62
# Episode: 8, Action: 0, Epsilon: 0.01, Reward: -34.25
# Episode: 8, Action: 0, Epsilon: 0.01, Reward: -34.89
# Episode: 8, Action: 2, Epsilon: 0.01, Reward: -35.54
# Episode: 8, Action: 2, Epsilon: 0.01, Reward: -36.199999999999996
# Episode: 8, Action: 2, Epsilon: 0.01, Reward: -36.87
# Episode: 8, Action: 3, Epsilon: 0.01, Reward: -37.55
# Episode: 8, Action: 3, Epsilon: 0.01, Reward: -38.239999999999995
# Episode: 8, Action: 3, Epsilon: 0.01, Reward: -38.94
# Episode: 8, Action: 1, Epsilon: 0.01, Reward: -39.65
# Episode: 8, Action: 1, Epsilon: 0.01, Reward: -40.37
# Episode: 8, Action: 1, Epsilon: 0.01, Reward: -41.099999999999994
# Episode: 8, Action: 1, Epsilon: 0.01, Reward: -41.839999999999996
# Episode: 8, Action: 2, Epsilon: 0.01, Reward: -42.589999999999996
# Episode: 8, Action: 0, Epsilon: 0.01, Reward: -43.589999999999996
# Episode: 8, Action: 1, Epsilon: 0.01, Reward: -44.589999999999996
# Episode: 8, Action: 2, Epsilon: 0.01, Reward: -45.37
# Episode: 8, Action: 2, Epsilon: 0.01, Reward: -46.37
# Episode: 8, Action: 0, Epsilon: 0.01, Reward: -47.37
# Episode: 8, Action: 1, Epsilon: 0.01, Reward: -48.37
# Episode: 8, Action: 3, Epsilon: 0.01, Reward: -49.19
# Episode: 8, Action: 3, Epsilon: 0.01, Reward: -50.019999999999996
# Episode: 8, Action: 1, Epsilon: 0.01, Reward: -50.86
# Episode: 8, Action: 0, Epsilon: 0.01, Reward: -51.71
# Episode: 8, Action: 3, Epsilon: 0.01, Reward: -52.71
# Episode: 8, Action: 0, Epsilon: 0.01, Reward: -53.58
# Episode: 8, Action: 2, Epsilon: 0.01, Reward: -54.58
# Episode: 8, Action: 3, Epsilon: 0.01, Reward: -55.58
# Episode: 8, Action: 0, Epsilon: 0.01, Reward: -56.48
# Episode: 8, Action: 3, Epsilon: 0.01, Reward: -57.48
# Episode: 8, Action: 2, Epsilon: 0.01, Reward: -58.48
# Episode: 8, Action: 0, Epsilon: 0.01, Reward: -59.41
# Episode: 8, Action: 3, Epsilon: 0.01, Reward: -60.41
# Episode: 8, Action: 2, Epsilon: 0.01, Reward: -61.41
# Episode: 8, Action: 0, Epsilon: 0.01, Reward: -62.37
# Episode: 8, Action: 0, Epsilon: 0.01, Reward: -63.37
# Episode: 8, Action: 3, Epsilon: 0.01, Reward: -64.37
# Episode: 8, Action: 2, Epsilon: 0.01, Reward: -65.36
# Episode: 8, Action: 1, Epsilon: 0.01, Reward: -66.36
# Episode: 9, Action: 3, Epsilon: 0.01, Reward: 0.0
# Episode: 9, Action: 3, Epsilon: 0.01, Reward: 1.0
# Episode: 10, Action: 0, Epsilon: 0.01, Reward: 0.0
# Episode: 10, Action: 0, Epsilon: 0.01, Reward: -0.01
# Episode: 10, Action: 3, Epsilon: 0.01, Reward: -0.03
# Episode: 10, Action: 3, Epsilon: 0.01, Reward: -0.06
# Episode: 10, Action: 0, Epsilon: 0.01, Reward: -1.06
# Episode: 10, Action: 1, Epsilon: 0.01, Reward: -2.06
# Episode: 10, Action: 2, Epsilon: 0.01, Reward: -2.12
# Episode: 10, Action: 1, Epsilon: 0.01, Reward: -3.12
# Episode: 10, Action: 3, Epsilon: 0.01, Reward: -3.2
# Episode: 10, Action: 3, Epsilon: 0.01, Reward: -4.2
# Episode: 10, Action: 2, Epsilon: 0.01, Reward: -4.3
# Episode: 10, Action: 3, Epsilon: 0.01, Reward: -4.41
# Episode: 10, Action: 2, Epsilon: 0.01, Reward: -4.53
# Episode: 10, Action: 3, Epsilon: 0.01, Reward: -4.66
# Episode: 10, Action: 2, Epsilon: 0.01, Reward: -4.8
# Episode: 10, Action: 3, Epsilon: 0.01, Reward: -4.95
# Episode: 10, Action: 2, Epsilon: 0.01, Reward: -5.11
# Episode: 10, Action: 3, Epsilon: 0.01, Reward: -5.28
# Episode: 10, Action: 2, Epsilon: 0.01, Reward: -5.46
# Episode: 10, Action: 2, Epsilon: 0.01, Reward: -5.65
# Episode: 10, Action: 3, Epsilon: 0.01, Reward: -5.8500000000000005
# Episode: 10, Action: 2, Epsilon: 0.01, Reward: -6.0600000000000005
# Episode: 10, Action: 3, Epsilon: 0.01, Reward: -6.28
# Episode: 10, Action: 2, Epsilon: 0.01, Reward: -6.510000000000001
# Episode: 10, Action: 0, Epsilon: 0.01, Reward: -6.750000000000001
# Episode: 10, Action: 0, Epsilon: 0.01, Reward: -7.000000000000001
# Episode: 10, Action: 0, Epsilon: 0.01, Reward: -7.260000000000001
# Episode: 10, Action: 0, Epsilon: 0.01, Reward: -7.530000000000001
# Episode: 10, Action: 3, Epsilon: 0.01, Reward: -7.810000000000001
# Episode: 10, Action: 2, Epsilon: 0.01, Reward: -8.100000000000001
# Episode: 10, Action: 2, Epsilon: 0.01, Reward: -8.400000000000002
# Episode: 10, Action: 0, Epsilon: 0.01, Reward: -9.400000000000002
# Episode: 10, Action: 2, Epsilon: 0.01, Reward: -9.720000000000002
# Episode: 10, Action: 2, Epsilon: 0.01, Reward: -10.720000000000002
# Episode: 10, Action: 1, Epsilon: 0.01, Reward: -11.720000000000002
# Episode: 10, Action: 2, Epsilon: 0.01, Reward: -12.720000000000002
# Episode: 10, Action: 2, Epsilon: 0.01, Reward: -13.720000000000002
# Episode: 10, Action: 3, Epsilon: 0.01, Reward: -14.090000000000002
# Episode: 10, Action: 3, Epsilon: 0.01, Reward: -14.470000000000002
# Episode: 10, Action: 0, Epsilon: 0.01, Reward: -15.470000000000002
# Episode: 10, Action: 3, Epsilon: 0.01, Reward: -15.870000000000003
# Episode: 10, Action: 1, Epsilon: 0.01, Reward: -16.870000000000005
# Episode: 10, Action: 0, Epsilon: 0.01, Reward: -17.870000000000005
# Episode: 10, Action: 3, Epsilon: 0.01, Reward: -18.300000000000004
# Episode: 10, Action: 1, Epsilon: 0.01, Reward: -19.300000000000004
# Episode: 10, Action: 0, Epsilon: 0.01, Reward: -20.300000000000004
# Episode: 10, Action: 2, Epsilon: 0.01, Reward: -20.760000000000005
# Episode: 10, Action: 2, Epsilon: 0.01, Reward: -21.230000000000004
# Episode: 10, Action: 2, Epsilon: 0.01, Reward: -21.710000000000004
# Episode: 10, Action: 1, Epsilon: 0.01, Reward: -22.710000000000004
# Episode: 10, Action: 2, Epsilon: 0.01, Reward: -23.210000000000004
# Episode: 10, Action: 0, Epsilon: 0.01, Reward: -24.210000000000004
# Episode: 10, Action: 3, Epsilon: 0.01, Reward: -24.730000000000004
# Episode: 10, Action: 3, Epsilon: 0.01, Reward: -25.260000000000005
# Episode: 10, Action: 3, Epsilon: 0.01, Reward: -25.800000000000004
# Episode: 10, Action: 3, Epsilon: 0.01, Reward: -26.350000000000005
# Episode: 10, Action: 3, Epsilon: 0.01, Reward: -27.350000000000005
# Episode: 10, Action: 2, Epsilon: 0.01, Reward: -27.920000000000005
# Episode: 10, Action: 3, Epsilon: 0.01, Reward: -28.500000000000004
# Episode: 10, Action: 1, Epsilon: 0.01, Reward: -29.500000000000004
# Episode: 10, Action: 3, Epsilon: 0.01, Reward: -30.500000000000004
# Episode: 10, Action: 0, Epsilon: 0.01, Reward: -31.500000000000004
# Episode: 10, Action: 2, Epsilon: 0.01, Reward: -32.120000000000005
# Episode: 10, Action: 2, Epsilon: 0.01, Reward: -32.75000000000001
# Episode: 10, Action: 2, Epsilon: 0.01, Reward: -33.39000000000001
# Episode: 10, Action: 2, Epsilon: 0.01, Reward: -34.040000000000006
# Episode: 10, Action: 3, Epsilon: 0.01, Reward: -34.7
# Episode: 10, Action: 3, Epsilon: 0.01, Reward: -35.370000000000005
# Episode: 10, Action: 1, Epsilon: 0.01, Reward: -36.050000000000004
# Episode: 10, Action: 0, Epsilon: 0.01, Reward: -36.74
# Episode: 10, Action: 3, Epsilon: 0.01, Reward: -37.440000000000005
# Episode: 10, Action: 1, Epsilon: 0.01, Reward: -38.440000000000005
# Episode: 10, Action: 0, Epsilon: 0.01, Reward: -39.440000000000005
# Episode: 10, Action: 2, Epsilon: 0.01, Reward: -40.17
# Episode: 10, Action: 0, Epsilon: 0.01, Reward: -41.17
# Episode: 10, Action: 1, Epsilon: 0.01, Reward: -41.92
# Episode: 10, Action: 1, Epsilon: 0.01, Reward: -42.68
# Episode: 10, Action: 0, Epsilon: 0.01, Reward: -43.45
# Episode: 10, Action: 3, Epsilon: 0.01, Reward: -44.45
# Episode: 10, Action: 2, Epsilon: 0.01, Reward: -45.45
# Episode: 10, Action: 0, Epsilon: 0.01, Reward: -46.25
# Episode: 10, Action: 2, Epsilon: 0.01, Reward: -47.06
# Episode: 10, Action: 1, Epsilon: 0.01, Reward: -48.06
# Episode: 10, Action: 0, Epsilon: 0.01, Reward: -49.06
# Episode: 10, Action: 2, Epsilon: 0.01, Reward: -49.900000000000006
# Episode: 10, Action: 0, Epsilon: 0.01, Reward: -50.900000000000006
# Episode: 10, Action: 1, Epsilon: 0.01, Reward: -51.900000000000006
# Episode: 10, Action: 2, Epsilon: 0.01, Reward: -52.900000000000006
# Episode: 10, Action: 3, Epsilon: 0.01, Reward: -53.78000000000001
# Episode: 10, Action: 3, Epsilon: 0.01, Reward: -54.67000000000001
# Episode: 10, Action: 3, Epsilon: 0.01, Reward: -55.57000000000001
# Episode: 10, Action: 3, Epsilon: 0.01, Reward: -56.480000000000004
# Episode: 10, Action: 2, Epsilon: 0.01, Reward: -57.400000000000006
# Episode: 10, Action: 2, Epsilon: 0.01, Reward: -58.330000000000005
# Episode: 10, Action: 1, Epsilon: 0.01, Reward: -59.27
# Episode: 10, Action: 1, Epsilon: 0.01, Reward: -60.220000000000006
# Episode: 10, Action: 1, Epsilon: 0.01, Reward: -61.18000000000001
# Episode: 10, Action: 0, Epsilon: 0.01, Reward: -62.150000000000006
# Episode: 10, Action: 3, Epsilon: 0.01, Reward: -63.150000000000006
# Episode: 10, Action: 2, Epsilon: 0.01, Reward: -64.15
# Episode: 10, Action: 0, Epsilon: 0.01, Reward: -65.15
# Episode: 11, Action: 2, Epsilon: 0.01, Reward: 0.0
# Episode: 11, Action: 0, Epsilon: 0.01, Reward: -0.01
# Episode: 11, Action: 0, Epsilon: 0.01, Reward: -0.03
# Episode: 11, Action: 0, Epsilon: 0.01, Reward: -0.06
# Episode: 11, Action: 1, Epsilon: 0.01, Reward: -0.1
# Episode: 11, Action: 3, Epsilon: 0.01, Reward: -0.15000000000000002
# Episode: 11, Action: 3, Epsilon: 0.01, Reward: -0.21000000000000002
# Episode: 11, Action: 2, Epsilon: 0.01, Reward: -0.28
# Episode: 11, Action: 3, Epsilon: 0.01, Reward: -0.36000000000000004
# Episode: 11, Action: 0, Epsilon: 0.01, Reward: -1.36
# Episode: 11, Action: 3, Epsilon: 0.01, Reward: -2.3600000000000003
# Episode: 11, Action: 1, Epsilon: 0.01, Reward: -3.3600000000000003
# Episode: 11, Action: 2, Epsilon: 0.01, Reward: -3.4800000000000004
# Episode: 11, Action: 1, Epsilon: 0.01, Reward: -4.48
# Episode: 11, Action: 0, Epsilon: 0.01, Reward: -5.48
# Episode: 11, Action: 2, Epsilon: 0.01, Reward: -5.630000000000001
# Episode: 11, Action: 0, Epsilon: 0.01, Reward: -5.790000000000001
# Episode: 11, Action: 1, Epsilon: 0.01, Reward: -5.960000000000001
# Episode: 11, Action: 2, Epsilon: 0.01, Reward: -6.960000000000001
# Episode: 11, Action: 1, Epsilon: 0.01, Reward: -7.150000000000001
# Episode: 11, Action: 0, Epsilon: 0.01, Reward: -7.350000000000001
# Episode: 11, Action: 3, Epsilon: 0.01, Reward: -7.560000000000001
# Episode: 11, Action: 3, Epsilon: 0.01, Reward: -7.780000000000001
# Episode: 11, Action: 2, Epsilon: 0.01, Reward: -8.010000000000002
# Episode: 11, Action: 2, Epsilon: 0.01, Reward: -8.250000000000002
# Episode: 11, Action: 1, Epsilon: 0.01, Reward: -8.500000000000002
# Episode: 11, Action: 2, Epsilon: 0.01, Reward: -9.500000000000002
# Episode: 11, Action: 3, Epsilon: 0.01, Reward: -10.500000000000002
# Episode: 11, Action: 1, Epsilon: 0.01, Reward: -10.780000000000001
# Episode: 11, Action: 0, Epsilon: 0.01, Reward: -11.07
# Episode: 11, Action: 1, Epsilon: 0.01, Reward: -11.370000000000001
# Episode: 11, Action: 1, Epsilon: 0.01, Reward: -12.370000000000001
# Episode: 11, Action: 2, Epsilon: 0.01, Reward: -13.370000000000001
# Episode: 11, Action: 3, Epsilon: 0.01, Reward: -13.700000000000001
# Episode: 11, Action: 2, Epsilon: 0.01, Reward: -14.040000000000001
# Episode: 11, Action: 3, Epsilon: 0.01, Reward: -14.39
# ...
# Episode: 583, Action: 1, Epsilon: 0.01, Reward: -0.28
# Episode: 583, Action: 1, Epsilon: 0.01, Reward: -0.36000000000000004
# Episode: 583, Action: 3, Epsilon: 0.01, Reward: -0.45000000000000007
# Episode: 583, Action: 3, Epsilon: 0.01, Reward: -0.55
# Episode: 583, Action: 3, Epsilon: 0.01, Reward: -0.66
# Episode: 583, Action: 3, Epsilon: 0.01, Reward: 0.33999999999999997
# Episode: 584, Action: 3, Epsilon: 0.01, Reward: 0.0
# Episode: 584, Action: 3, Epsilon: 0.01, Reward: -0.01
# Episode: 584, Action: 3, Epsilon: 0.01, Reward: -0.03
# Episode: 584, Action: 3, Epsilon: 0.01, Reward: -0.06
# Episode: 584, Action: 3, Epsilon: 0.01, Reward: -0.1
# Episode: 584, Action: 3, Epsilon: 0.01, Reward: -0.15000000000000002
# Episode: 584, Action: 1, Epsilon: 0.01, Reward: -0.21000000000000002
# Episode: 584, Action: 1, Epsilon: 0.01, Reward: -0.28
# Episode: 584, Action: 1, Epsilon: 0.01, Reward: -0.36000000000000004
# Episode: 584, Action: 1, Epsilon: 0.01, Reward: -0.45000000000000007
# Episode: 584, Action: 1, Epsilon: 0.01, Reward: -0.55
# Episode: 584, Action: 1, Epsilon: 0.01, Reward: -0.66
# Episode: 584, Action: 1, Epsilon: 0.01, Reward: -0.78
# Episode: 584, Action: 1, Epsilon: 0.01, Reward: -0.91
# Episode: 584, Action: 1, Epsilon: 0.01, Reward: -1.05
# Episode: 584, Action: 1, Epsilon: 0.01, Reward: -1.2
# Episode: 584, Action: 1, Epsilon: 0.01, Reward: -1.3599999999999999
# Episode: 584, Action: 1, Epsilon: 0.01, Reward: -1.5299999999999998
# Episode: 584, Action: 2, Epsilon: 0.01, Reward: -1.7099999999999997
# Episode: 584, Action: 2, Epsilon: 0.01, Reward: -1.8999999999999997
# Episode: 584, Action: 0, Epsilon: 0.01, Reward: -2.0999999999999996
# Episode: 584, Action: 0, Epsilon: 0.01, Reward: -1.0999999999999996
# Episode: 585, Action: 0, Epsilon: 0.01, Reward: 0.0
# Episode: 585, Action: 1, Epsilon: 0.01, Reward: -0.01
# Episode: 585, Action: 1, Epsilon: 0.01, Reward: -0.03
# Episode: 585, Action: 3, Epsilon: 0.01, Reward: -0.06
# Episode: 585, Action: 3, Epsilon: 0.01, Reward: -0.1
# Episode: 585, Action: 3, Epsilon: 0.01, Reward: -0.15000000000000002
# Episode: 585, Action: 3, Epsilon: 0.01, Reward: -0.21000000000000002
# Episode: 585, Action: 3, Epsilon: 0.01, Reward: -0.28
# Episode: 585, Action: 3, Epsilon: 0.01, Reward: 0.72
# Episode: 586, Action: 3, Epsilon: 0.01, Reward: 0.0
# Episode: 586, Action: 3, Epsilon: 0.01, Reward: -0.01
# Episode: 586, Action: 1, Epsilon: 0.01, Reward: -0.03
# Episode: 586, Action: 1, Epsilon: 0.01, Reward: -0.06
# Episode: 586, Action: 1, Epsilon: 0.01, Reward: -0.1
# Episode: 586, Action: 1, Epsilon: 0.01, Reward: -0.15000000000000002
# Episode: 586, Action: 1, Epsilon: 0.01, Reward: -0.21000000000000002
# Episode: 586, Action: 1, Epsilon: 0.01, Reward: -0.28
# Episode: 586, Action: 1, Epsilon: 0.01, Reward: -0.36000000000000004
# Episode: 586, Action: 1, Epsilon: 0.01, Reward: -0.45000000000000007
# Episode: 586, Action: 1, Epsilon: 0.01, Reward: -0.55
# Episode: 586, Action: 1, Epsilon: 0.01, Reward: -0.66
# Episode: 586, Action: 1, Epsilon: 0.01, Reward: -0.78
# Episode: 586, Action: 1, Epsilon: 0.01, Reward: -0.91
# Episode: 586, Action: 2, Epsilon: 0.01, Reward: -1.05
# Episode: 586, Action: 2, Epsilon: 0.01, Reward: -1.2
# Episode: 586, Action: 0, Epsilon: 0.01, Reward: -1.3599999999999999
# Episode: 586, Action: 0, Epsilon: 0.01, Reward: -0.3599999999999999
# Episode: 587, Action: 3, Epsilon: 0.01, Reward: 0.0
# Episode: 587, Action: 3, Epsilon: 0.01, Reward: -0.01
# Episode: 587, Action: 1, Epsilon: 0.01, Reward: -0.03
# Episode: 587, Action: 1, Epsilon: 0.01, Reward: -0.06
# Episode: 587, Action: 3, Epsilon: 0.01, Reward: -0.1
# Episode: 587, Action: 3, Epsilon: 0.01, Reward: -0.15000000000000002
# Episode: 587, Action: 1, Epsilon: 0.01, Reward: -0.21000000000000002
# Episode: 587, Action: 1, Epsilon: 0.01, Reward: -0.28
# Episode: 587, Action: 1, Epsilon: 0.01, Reward: -0.36000000000000004
# Episode: 587, Action: 1, Epsilon: 0.01, Reward: -0.45000000000000007
# Episode: 587, Action: 1, Epsilon: 0.01, Reward: -0.55
# Episode: 587, Action: 1, Epsilon: 0.01, Reward: -0.66
# Episode: 587, Action: 3, Epsilon: 0.01, Reward: -0.78
# Episode: 587, Action: 3, Epsilon: 0.01, Reward: -0.91
# Episode: 587, Action: 3, Epsilon: 0.01, Reward: -1.05
# Episode: 587, Action: 3, Epsilon: 0.01, Reward: -0.050000000000000044
# Episode: 588, Action: 1, Epsilon: 0.01, Reward: 0.0
# Episode: 588, Action: 1, Epsilon: 0.01, Reward: -0.01
# Episode: 588, Action: 3, Epsilon: 0.01, Reward: -0.03
# Episode: 588, Action: 3, Epsilon: 0.01, Reward: -0.06
# Episode: 588, Action: 3, Epsilon: 0.01, Reward: -0.1
# Episode: 588, Action: 3, Epsilon: 0.01, Reward: -0.15000000000000002
# Episode: 588, Action: 1, Epsilon: 0.01, Reward: -0.21000000000000002
# Episode: 588, Action: 1, Epsilon: 0.01, Reward: -0.28
# Episode: 588, Action: 1, Epsilon: 0.01, Reward: -0.36000000000000004
# Episode: 588, Action: 1, Epsilon: 0.01, Reward: -0.45000000000000007
# Episode: 588, Action: 2, Epsilon: 0.01, Reward: -0.55
# Episode: 588, Action: 2, Epsilon: 0.01, Reward: -0.66
# Episode: 588, Action: 0, Epsilon: 0.01, Reward: -0.78
# Episode: 588, Action: 0, Epsilon: 0.01, Reward: 0.21999999999999997
# Episode: 589, Action: 3, Epsilon: 0.01, Reward: 0.0
# Episode: 589, Action: 1, Epsilon: 0.01, Reward: -0.01
# Episode: 589, Action: 1, Epsilon: 0.01, Reward: -0.03
# Episode: 589, Action: 1, Epsilon: 0.01, Reward: -0.06
# Episode: 589, Action: 1, Epsilon: 0.01, Reward: -0.1
# Episode: 589, Action: 1, Epsilon: 0.01, Reward: -0.15000000000000002
# Episode: 589, Action: 1, Epsilon: 0.01, Reward: -0.21000000000000002
# Episode: 589, Action: 3, Epsilon: 0.01, Reward: -0.28
# Episode: 589, Action: 3, Epsilon: 0.01, Reward: -0.36000000000000004
# Episode: 589, Action: 3, Epsilon: 0.01, Reward: -0.45000000000000007
# Episode: 589, Action: 3, Epsilon: 0.01, Reward: 0.5499999999999999
# Episode: 590, Action: 2, Epsilon: 0.01, Reward: 0.0
# Episode: 590, Action: 0, Epsilon: 0.01, Reward: -0.01
# Episode: 590, Action: 0, Epsilon: 0.01, Reward: -0.03
# Episode: 590, Action: 0, Epsilon: 0.01, Reward: -0.06
# Episode: 590, Action: 0, Epsilon: 0.01, Reward: -0.1
# Episode: 590, Action: 0, Epsilon: 0.01, Reward: -0.15000000000000002
# Episode: 590, Action: 0, Epsilon: 0.01, Reward: -0.21000000000000002
# Episode: 590, Action: 3, Epsilon: 0.01, Reward: -0.28
# Episode: 590, Action: 3, Epsilon: 0.01, Reward: -0.36000000000000004
# Episode: 590, Action: 3, Epsilon: 0.01, Reward: -0.45000000000000007
# Episode: 590, Action: 3, Epsilon: 0.01, Reward: -0.55
# Episode: 590, Action: 1, Epsilon: 0.01, Reward: -0.66
# Episode: 590, Action: 1, Epsilon: 0.01, Reward: -0.78
# Episode: 590, Action: 1, Epsilon: 0.01, Reward: -0.91
# Episode: 590, Action: 1, Epsilon: 0.01, Reward: -1.05
# Episode: 590, Action: 3, Epsilon: 0.01, Reward: -1.2
# Episode: 590, Action: 3, Epsilon: 0.01, Reward: -1.3599999999999999
# Episode: 590, Action: 3, Epsilon: 0.01, Reward: -1.5299999999999998
# Episode: 590, Action: 3, Epsilon: 0.01, Reward: -1.7099999999999997
# Episode: 590, Action: 3, Epsilon: 0.01, Reward: -1.8999999999999997
# Episode: 590, Action: 3, Epsilon: 0.01, Reward: -0.8999999999999997
# Episode: 591, Action: 2, Epsilon: 0.01, Reward: 0.0
# Episode: 591, Action: 2, Epsilon: 0.01, Reward: -0.01
# Episode: 591, Action: 2, Epsilon: 0.01, Reward: -0.03
# Episode: 591, Action: 2, Epsilon: 0.01, Reward: -0.06
# Episode: 591, Action: 2, Epsilon: 0.01, Reward: -0.1
# Episode: 591, Action: 2, Epsilon: 0.01, Reward: -0.15000000000000002
# Episode: 591, Action: 2, Epsilon: 0.01, Reward: -0.21000000000000002
# Episode: 591, Action: 0, Epsilon: 0.01, Reward: -0.28
# Episode: 591, Action: 0, Epsilon: 0.01, Reward: -0.36000000000000004
# Episode: 591, Action: 0, Epsilon: 0.01, Reward: -0.45000000000000007
# Episode: 591, Action: 0, Epsilon: 0.01, Reward: -0.55
# Episode: 591, Action: 0, Epsilon: 0.01, Reward: -0.66
# Episode: 591, Action: 2, Epsilon: 0.01, Reward: -1.6600000000000001
# Episode: 591, Action: 0, Epsilon: 0.01, Reward: -1.79
# Episode: 591, Action: 3, Epsilon: 0.01, Reward: -1.9300000000000002
# Episode: 591, Action: 3, Epsilon: 0.01, Reward: -2.08
# Episode: 591, Action: 3, Epsilon: 0.01, Reward: -2.24
# Episode: 591, Action: 3, Epsilon: 0.01, Reward: -2.41
# Episode: 591, Action: 1, Epsilon: 0.01, Reward: -2.5900000000000003
# Episode: 591, Action: 1, Epsilon: 0.01, Reward: -2.7800000000000002
# Episode: 591, Action: 1, Epsilon: 0.01, Reward: -2.9800000000000004
# Episode: 591, Action: 1, Epsilon: 0.01, Reward: -3.1900000000000004
# Episode: 591, Action: 3, Epsilon: 0.01, Reward: -3.4100000000000006
# Episode: 591, Action: 3, Epsilon: 0.01, Reward: -3.6400000000000006
# Episode: 591, Action: 3, Epsilon: 0.01, Reward: -3.880000000000001
# Episode: 591, Action: 3, Epsilon: 0.01, Reward: -4.130000000000001
# Episode: 591, Action: 3, Epsilon: 0.01, Reward: -4.390000000000001
# Episode: 591, Action: 3, Epsilon: 0.01, Reward: -3.3900000000000006
# Episode: 592, Action: 2, Epsilon: 0.01, Reward: 0.0
# Episode: 592, Action: 2, Epsilon: 0.01, Reward: -0.01
# Episode: 592, Action: 0, Epsilon: 0.01, Reward: -0.03
# Episode: 592, Action: 0, Epsilon: 0.01, Reward: -0.06
# Episode: 592, Action: 0, Epsilon: 0.01, Reward: -0.1
# Episode: 592, Action: 0, Epsilon: 0.01, Reward: -0.15000000000000002
# Episode: 592, Action: 0, Epsilon: 0.01, Reward: -0.21000000000000002
# Episode: 592, Action: 0, Epsilon: 0.01, Reward: -0.28
# Episode: 592, Action: 3, Epsilon: 0.01, Reward: -0.36000000000000004
# Episode: 592, Action: 3, Epsilon: 0.01, Reward: -0.45000000000000007
# Episode: 592, Action: 3, Epsilon: 0.01, Reward: -0.55
# Episode: 592, Action: 3, Epsilon: 0.01, Reward: -0.66
# Episode: 592, Action: 1, Epsilon: 0.01, Reward: -0.78
# Episode: 592, Action: 1, Epsilon: 0.01, Reward: -0.91
# Episode: 592, Action: 1, Epsilon: 0.01, Reward: -1.05
# Episode: 592, Action: 1, Epsilon: 0.01, Reward: -1.2
# Episode: 592, Action: 3, Epsilon: 0.01, Reward: -1.3599999999999999
# Episode: 592, Action: 3, Epsilon: 0.01, Reward: -1.5299999999999998
# Episode: 592, Action: 3, Epsilon: 0.01, Reward: -1.7099999999999997
# Episode: 592, Action: 3, Epsilon: 0.01, Reward: -1.8999999999999997
# Episode: 592, Action: 3, Epsilon: 0.01, Reward: -2.0999999999999996
# Episode: 592, Action: 3, Epsilon: 0.01, Reward: -1.0999999999999996
# Episode: 593, Action: 2, Epsilon: 0.01, Reward: 0.0
# Episode: 593, Action: 2, Epsilon: 0.01, Reward: -0.01
# Episode: 593, Action: 0, Epsilon: 0.01, Reward: -0.03
# Episode: 593, Action: 0, Epsilon: 0.01, Reward: -0.06
# Episode: 593, Action: 0, Epsilon: 0.01, Reward: -0.1
# Episode: 593, Action: 0, Epsilon: 0.01, Reward: -0.15000000000000002
# Episode: 593, Action: 0, Epsilon: 0.01, Reward: -0.21000000000000002
# Episode: 593, Action: 0, Epsilon: 0.01, Reward: -0.28
# Episode: 593, Action: 3, Epsilon: 0.01, Reward: -0.36000000000000004
# Episode: 593, Action: 3, Epsilon: 0.01, Reward: -0.45000000000000007
# Episode: 593, Action: 3, Epsilon: 0.01, Reward: -0.55
# Episode: 593, Action: 3, Epsilon: 0.01, Reward: -0.66
# Episode: 593, Action: 1, Epsilon: 0.01, Reward: -0.78
# Episode: 593, Action: 1, Epsilon: 0.01, Reward: -0.91
# Episode: 593, Action: 1, Epsilon: 0.01, Reward: -1.05
# Episode: 593, Action: 1, Epsilon: 0.01, Reward: -1.2
# Episode: 593, Action: 3, Epsilon: 0.01, Reward: -1.3599999999999999
# Episode: 593, Action: 3, Epsilon: 0.01, Reward: -1.5299999999999998
# Episode: 593, Action: 3, Epsilon: 0.01, Reward: -1.7099999999999997
# Episode: 593, Action: 3, Epsilon: 0.01, Reward: -1.8999999999999997
# Episode: 593, Action: 3, Epsilon: 0.01, Reward: -2.0999999999999996
# Episode: 593, Action: 3, Epsilon: 0.01, Reward: -1.0999999999999996
# Episode: 594, Action: 1, Epsilon: 0.01, Reward: 0.0
# Episode: 594, Action: 1, Epsilon: 0.01, Reward: -0.01
# Episode: 594, Action: 3, Epsilon: 0.01, Reward: -0.03
# Episode: 594, Action: 3, Epsilon: 0.01, Reward: -0.06
# Episode: 594, Action: 3, Epsilon: 0.01, Reward: -0.1
# Episode: 594, Action: 3, Epsilon: 0.01, Reward: -0.15000000000000002
# Episode: 594, Action: 1, Epsilon: 0.01, Reward: -0.21000000000000002
# Episode: 594, Action: 1, Epsilon: 0.01, Reward: -0.28
# Episode: 594, Action: 1, Epsilon: 0.01, Reward: -0.36000000000000004
# Episode: 594, Action: 1, Epsilon: 0.01, Reward: -0.45000000000000007
# Episode: 594, Action: 3, Epsilon: 0.01, Reward: -0.55
# Episode: 594, Action: 3, Epsilon: 0.01, Reward: -0.66
# Episode: 594, Action: 3, Epsilon: 0.01, Reward: -0.78
# Episode: 594, Action: 3, Epsilon: 0.01, Reward: -0.91
# Episode: 594, Action: 3, Epsilon: 0.01, Reward: -1.05
# Episode: 594, Action: 3, Epsilon: 0.01, Reward: -0.050000000000000044
# Episode: 595, Action: 3, Epsilon: 0.01, Reward: 0.0
# Episode: 595, Action: 3, Epsilon: 0.01, Reward: -0.01
# Episode: 595, Action: 3, Epsilon: 0.01, Reward: 0.99
# Episode: 596, Action: 2, Epsilon: 0.01, Reward: 0.0
# Episode: 596, Action: 1, Epsilon: 0.01, Reward: -0.01
# Episode: 596, Action: 1, Epsilon: 0.01, Reward: -0.03
# Episode: 596, Action: 3, Epsilon: 0.01, Reward: -0.06
# Episode: 596, Action: 3, Epsilon: 0.01, Reward: -0.1
# Episode: 596, Action: 3, Epsilon: 0.01, Reward: -0.15000000000000002
# Episode: 596, Action: 3, Epsilon: 0.01, Reward: -0.21000000000000002
# Episode: 596, Action: 1, Epsilon: 0.01, Reward: -0.28
# Episode: 596, Action: 1, Epsilon: 0.01, Reward: -0.36000000000000004
# Episode: 596, Action: 1, Epsilon: 0.01, Reward: -0.45000000000000007
# Episode: 596, Action: 1, Epsilon: 0.01, Reward: -0.55
# Episode: 596, Action: 2, Epsilon: 0.01, Reward: -0.66
# Episode: 596, Action: 2, Epsilon: 0.01, Reward: -0.78
# Episode: 596, Action: 0, Epsilon: 0.01, Reward: -0.91
# Episode: 596, Action: 0, Epsilon: 0.01, Reward: 0.08999999999999997
# Episode: 597, Action: 2, Epsilon: 0.01, Reward: 0.0
# Episode: 597, Action: 1, Epsilon: 0.01, Reward: -0.01
# Episode: 597, Action: 1, Epsilon: 0.01, Reward: -0.03
# Episode: 597, Action: 3, Epsilon: 0.01, Reward: -0.06
# Episode: 597, Action: 3, Epsilon: 0.01, Reward: -0.1
# Episode: 597, Action: 3, Epsilon: 0.01, Reward: -0.15000000000000002
# Episode: 597, Action: 3, Epsilon: 0.01, Reward: -0.21000000000000002
# Episode: 597, Action: 1, Epsilon: 0.01, Reward: -0.28
# Episode: 597, Action: 1, Epsilon: 0.01, Reward: -0.36000000000000004
# Episode: 597, Action: 1, Epsilon: 0.01, Reward: -0.45000000000000007
# Episode: 597, Action: 1, Epsilon: 0.01, Reward: -0.55
# Episode: 597, Action: 2, Epsilon: 0.01, Reward: -0.66
# Episode: 597, Action: 2, Epsilon: 0.01, Reward: -0.78
# Episode: 597, Action: 0, Epsilon: 0.01, Reward: -0.91
# Episode: 597, Action: 0, Epsilon: 0.01, Reward: 0.08999999999999997
# Episode: 598, Action: 1, Epsilon: 0.01, Reward: 0.0
# Episode: 598, Action: 1, Epsilon: 0.01, Reward: -0.01
# Episode: 598, Action: 1, Epsilon: 0.01, Reward: -0.03
# Episode: 598, Action: 1, Epsilon: 0.01, Reward: -0.06
# Episode: 598, Action: 1, Epsilon: 0.01, Reward: -0.1
# Episode: 598, Action: 1, Epsilon: 0.01, Reward: -0.15000000000000002
# Episode: 598, Action: 1, Epsilon: 0.01, Reward: -0.21000000000000002
# Episode: 598, Action: 2, Epsilon: 0.01, Reward: -0.28
# Episode: 598, Action: 2, Epsilon: 0.01, Reward: -0.36000000000000004
# Episode: 598, Action: 0, Epsilon: 0.01, Reward: -0.45000000000000007
# Episode: 598, Action: 0, Epsilon: 0.01, Reward: 0.5499999999999999
# Episode: 599, Action: 1, Epsilon: 0.01, Reward: 0.0
# Episode: 599, Action: 1, Epsilon: 0.01, Reward: -0.01
# Episode: 599, Action: 1, Epsilon: 0.01, Reward: -0.03
# Episode: 599, Action: 1, Epsilon: 0.01, Reward: -0.06
# Episode: 599, Action: 1, Epsilon: 0.01, Reward: -0.1
# Episode: 599, Action: 1, Epsilon: 0.01, Reward: -0.15000000000000002
# Episode: 599, Action: 3, Epsilon: 0.01, Reward: -0.21000000000000002
# Episode: 599, Action: 3, Epsilon: 0.01, Reward: -0.28
# Episode: 599, Action: 3, Epsilon: 0.01, Reward: -0.36000000000000004
# Episode: 599, Action: 3, Epsilon: 0.01, Reward: -0.45000000000000007
# Episode: 599, Action: 1, Epsilon: 0.01, Reward: -0.55
# Episode: 599, Action: 1, Epsilon: 0.01, Reward: -0.66
# Episode: 599, Action: 1, Epsilon: 0.01, Reward: -0.78
# Episode: 599, Action: 1, Epsilon: 0.01, Reward: -0.91
# Episode: 599, Action: 2, Epsilon: 0.01, Reward: -1.05
# Episode: 599, Action: 2, Epsilon: 0.01, Reward: -1.2
# Episode: 599, Action: 0, Epsilon: 0.01, Reward: -1.3599999999999999
# Episode: 599, Action: 0, Epsilon: 0.01, Reward: -0.3599999999999999
# Average episode reward: 295.0

# %%
visualize_agent_brain(agent, env)

# %%
# Takes a bit to run, so commented out for now
# animate_run(img)

# %% [markdown]
#  ## 3. Play with parameters and analyse results
#
# Finally, you will describe, evaluate, and interpret the results obtained from the two RL agents. Additionally, compare your agents with the provided Random Agent. Feel free to utilize the provided helper functions for evaluating your agents. Some important points are:
#
# - Both quantified evaluation and human evaluation are needed in the report. The quantified evaluation should focus on the measurement of reward. In the human evaluation, you can use the provided visual tools to interpret your results. Your report should include at least one plot presenting comparable measures for the different agents.
#
# - While evaluating the results of Agent 2 (with SARSA algorithm), please try at least 2 different values of **epsilon** (expect 0) and discuss the influence of different epsilon values on the results. In the end, please identify a reasonable epsilon value that could balance the exploration and exploitation, then fix this value for comparing the two agents. Present your trails and results in the report.
#
# - In the report, you also need to parcitularly describe and discuss the similarity and difference of results from two RL agents (hint: on-policy VS off-policy). For this, please make sure that the compared results are obtained from the same environment (the same maze for two different agents). Also, while evaluating the results of two agents, please try at least 2 different values of **gamma**. In this way, you could discuss the influence of this discount factor in your report.
#
# - Please run the simulation multiple times and average the results for all your findings.

# %%
def QL_simulate(testsize, epsilon, alpha, gamma, epsilon_decay: bool = False):
    expanded_states_set = set()  # For the state-counter. Is a set, so it shouldn't take duplicates
    agent = QL_Agent(env, epsilon, alpha, gamma)
    test_reward = {}
    for episode in tqdm(range(size)):
        state = env.reset()
        done = False
        episode_reward = 0

        while not done:
            action = agent.select_action(state)
            next_state, reward, terminated, truncated = env.step(action)
            expanded_states_set.add(tuple(next_state)) # +1 to state counter
            next_action = agent.select_action(next_state)
            done = terminated or truncated
            episode_reward += reward

            agent.learn(state, action, next_state, next_action, reward, done)
            state = next_state
            if isinstance(agent, SARSA_Agent):
                action = next_action    # SARSA's next action is predetermined

        if epsilon > 0.012 and epsilon_decay == True:
            if episode % 10 == 0:
                epsilon -= 0.002

        # reward tracking
        if episode % 50 == 0:
            test_reward[episode] = episode_reward

        

    eval_avgreward = sum(test_reward.values()) / len(test_reward)
    states_explored_counter = len(expanded_states_set)  # Number of unique states visited
    return  eval_avgreward, testsize, test_reward, states_explored_counter

# %%
# define evaluation values
param_settings = [
    #{"epsilon": 0.01, "alpha": 0.8, "gamma": 0.99, "epsilon_decay": False},
    #{"epsilon": 0.01, "alpha": 0.8, "gamma": 0.99, "epsilon_decay": True},
    {"epsilon": 0.1, "alpha": 0.8, "gamma": 0.99, "epsilon_decay": False},
    {"epsilon": 0.1, "alpha": 0.8, "gamma": 0.99, "epsilon_decay": True},
    {"epsilon": 0.5, "alpha": 0.8, "gamma": 0.99, "epsilon_decay": False},
    {"epsilon": 0.5, "alpha": 0.8, "gamma": 0.99, "epsilon_decay": True}
    #{"epsilon": 0.02, "alpha": 0.8, "gamma": 0.99}
    #{"epsilon": 0.03, "alpha": 0.8, "gamma": 0.99}
    #{"epsilon": 0.04, "alpha": 0.8, "gamma": 0.99}
    #{"epsilon": 0.05, "alpha": 0.8, "gamma": 0.99}
    #{"epsilon": 0.10, "alpha": 0.8, "gamma": 0.99},
    #{"epsilon": 0.50, "alpha": 0.8, "gamma": 0.99},
    #{"epsilon": 0.80, "alpha": 0.8, "gamma": 0.99}
]

# %%
plt.figure()
for setting in param_settings:  # testing epsilon
    eval_avgreward, testsize, test_reward, states_explored_counter = QL_simulate(testsize=3000, epsilon=setting["epsilon"], alpha=setting["alpha"], gamma=setting["gamma"])
    print(testsize, setting, eval_avgreward, states_explored_counter)
    plt.plot(list(test_reward.keys()), list(test_reward.values()), label=str(setting["epsilon"]))

plt.xlabel("Episode")
plt.ylabel("Total Reward")
plt.legend()
plt.show()
# Out:
#   0%|          | 0/600 [00:00<?, ?it/s]
# 3000 {'epsilon': 0.01, 'alpha': 0.8, 'gamma': 0.99, 'epsilon_decay': False} -9.482499999999998 99
#   0%|          | 0/600 [00:00<?, ?it/s]
# 3000 {'epsilon': 0.01, 'alpha': 0.8, 'gamma': 0.99, 'epsilon_decay': True} -6.439166666666668 99
#   0%|          | 0/600 [00:00<?, ?it/s]
# 3000 {'epsilon': 0.1, 'alpha': 0.8, 'gamma': 0.99, 'epsilon_decay': False} -11.691666666666665 99
#   0%|          | 0/600 [00:00<?, ?it/s]
# 3000 {'epsilon': 0.1, 'alpha': 0.8, 'gamma': 0.99, 'epsilon_decay': True} -10.139166666666666 99

# %%
print(states_explored_counter)
# Out:
# 99

# %% [markdown]
# # Bonus Tasks
#
# We would like to challenge you with the following bonus task. For each task that is successfully completed, you may obtain max. 1 extra point.
#
# 1. Implement a third RL agent using another RL algorithm (e.g. Monte Carlo methods, Expected SARSA or even neural network-based ones) and discuss your findings. Compare this third agent with the above ones and explain why this is a better (or worse) RL algorithm. You are allowed to reuse exsiting packages, but please cite them, test them in advance, and make sure that you can explain the used algorithm using your own words.
#
# 2. Can you explore and show other evaluation results? If so, implement and present one extra result (e.g. a plot). And please explain why it is a good evaluation method for our task or how it shows the difference between two RL agents/algorithms.
